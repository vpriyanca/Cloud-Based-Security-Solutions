# %%
import os
import pymysql
import bcrypt
from getpass import getpass
import base64
import hashlib
from cryptography.hazmat.primitives.ciphers import Cipher, algorithms, modes
from cryptography.hazmat.backends import default_backend
from prettytable import PrettyTable
from faker import Faker
import random

# AES Encryption setup
def generate_aes_key():
    return os.urandom(32)  # AES key size

def encrypt_data_aes(data, key):
    iv = os.urandom(16)
    cipher = Cipher(algorithms.AES(key), modes.CBC(iv), backend=default_backend())
    encryptor = cipher.encryptor()
    padded_data = data + ' ' * (16 - len(data) % 16)
    encrypted_data = encryptor.update(padded_data.encode()) + encryptor.finalize()
    return base64.b64encode(iv + encrypted_data).decode('utf-8')

def decrypt_data_aes(data, key):
    try:
        data = base64.b64decode(data)
        iv = data[:16]
        encrypted_data = data[16:]
        cipher = Cipher(algorithms.AES(key), modes.CBC(iv), backend=default_backend())
        decryptor = cipher.decryptor()
        decrypted_data = decryptor.update(encrypted_data) + decryptor.finalize()
        return decrypted_data.rstrip().decode()
    except Exception as e:
        print(f"Decryption failed with error: {e}")
        return None

def get_user_role(cursor, username):
    try:
        cursor.execute("""
            SELECT role FROM user_credentials 
            WHERE username = %s
        """, (username,))
        user_record = cursor.fetchone()
        if user_record:
            return user_record['role']
    except Exception as e:
        print(f"Error getting user role: {e}")
        return None
    
# Generate record hash for integrity check
def generate_record_hash(patient_data):
    record_str = ''.join(str(patient_data[field]) for field in sorted(patient_data))
    return hashlib.sha256(record_str.encode()).hexdigest()

# Validate patient data
def validate_patient_data(patient_data):
    if patient_data['age'] < 0 or patient_data['weight'] < 0.0:
        raise ValueError("Age and weight should not be negative.")
    if not patient_data['first_name'] or not patient_data['last_name']:
        raise ValueError("First name and last name are required.")

# Populate patient data
def populate_patient_data(connection, cursor, num_records=100):
    fake = Faker()
    for _ in range(num_records):
        patient_data = {
            'first_name': fake.first_name(),
            'last_name': fake.last_name(),
            'gender': random.choice([True, False]),  # True for Male, False for Female
            'age': random.randint(0, 100),
            'weight': round(random.uniform(50.0, 100.0), 2),
            'height': round(random.uniform(150.0, 200.0), 2),
            'health_history': fake.text(),
            'record_hash': ''  # Placeholder for record hash
        }
        patient_data['record_hash'] = generate_record_hash(patient_data)
        insert_patient_data(connection, cursor, patient_data, 'admin')

# Create user and patient tables
# Create user table
def create_user_table(cursor):
    cursor.execute("""
        CREATE TABLE IF NOT EXISTS user_credentials (
            id INT AUTO_INCREMENT PRIMARY KEY,
            username VARCHAR(100) UNIQUE NOT NULL,
            password_hash VARBINARY(256) NOT NULL,
            role ENUM('admin', 'user') NOT NULL
        );
    """)

# Create patient table
def create_patient_table(cursor):
    cursor.execute("""
        CREATE TABLE IF NOT EXISTS patient_info (
            id INT AUTO_INCREMENT PRIMARY KEY,
            first_name VARCHAR(100),
            last_name VARCHAR(100),
            encrypted_gender VARBINARY(256),
            encrypted_age VARBINARY(256),
            weight FLOAT,
            height FLOAT,
            health_history TEXT,
            record_hash VARBINARY(256) NOT NULL,
            key_gender VARBINARY(256),
            key_age VARBINARY(256)
        );
    """)

# Register new user
def register_user(connection, cursor, username, password, role):
    password_hash = bcrypt.hashpw(password.encode('utf-8'), bcrypt.gensalt())
    try:
        cursor.execute("""
            INSERT INTO user_credentials (username, password_hash, role) 
            VALUES (%s, %s, %s)
        """, (username, password_hash, role))
        connection.commit()
    except pymysql.err.IntegrityError:
        print("Username already exists.")

# Authenticate user
def authenticate_user(cursor, username, password):
    cursor.execute("""
        SELECT password_hash FROM user_credentials 
        WHERE username = %s
    """, (username,))
    user_record = cursor.fetchone()
    if user_record and bcrypt.checkpw(password.encode('utf-8'), user_record['password_hash']):
        return True
    else:
        return False
    
# Function to verify data integrity
def verify_data_integrity(patient_data, stored_hash):
    calculated_hash = generate_record_hash(patient_data)
    return calculated_hash == stored_hash

# Function to generate checksum for a set of records
def generate_checksum(records):
    checksum = 0
    for record in records:
        checksum ^= int(hashlib.sha256(str(record).encode()).hexdigest(), 16)
    return checksum

# Function to add randomized padding for sensitive data
def pad_sensitive_data(data):
    padding_length = random.randint(1, 10)  # Random padding length
    return data + ('*' * padding_length)

# Insert patient data with validation and encryption
def insert_patient_data(connection, cursor, patient_data, user_role):
    try:
        if user_role != 'admin':  
            raise PermissionError("Permission denied.")

        validate_patient_data(patient_data)
        
        gender_str = pad_sensitive_data(str(int(patient_data['gender'])))  # Padding gender data
        age_str = pad_sensitive_data(str(patient_data['age']))  # Padding age data

        key_gender = generate_aes_key()
        key_age = generate_aes_key()

        encrypted_gender = encrypt_data_aes(gender_str, key_gender)
        encrypted_age = encrypt_data_aes(age_str, key_age)

        cursor.execute("""
            INSERT INTO patient_info (
                first_name, last_name, encrypted_gender, encrypted_age, weight, height, health_history, record_hash, key_gender, key_age
            ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
        """, (
            patient_data['first_name'],
            patient_data['last_name'],
            encrypted_gender,
            encrypted_age,
            patient_data['weight'],
            patient_data['height'],
            patient_data['health_history'],
            patient_data['record_hash'],
            base64.b64encode(key_gender).decode('utf-8'),
            base64.b64encode(key_age).decode('utf-8')
        ))
        connection.commit()
        print("Data inserted successfully.")
    except Exception as e:
        print(f"Error inserting data: {e}")

# Designed to interactively collect patient information from the admin
def add_patient_data(connection, cursor):
    print("Adding new patient data.")

    try:
        patient_data = {
            'first_name': input("Enter patient's first name: "),
            'last_name': input("Enter patient's last name: "),
            'gender': bool(input("Enter patient's gender (True for male, False for female): ")),
            'age': int(input("Enter patient's age: ")),
            'weight': float(input("Enter patient's weight: ")),
            'height': float(input("Enter patient's height: ")),
            'health_history': input("Enter patient's health history: "),
            'record_hash': ''  # Placeholder for record hash
        }

        validate_patient_data(patient_data)
        patient_data['record_hash'] = generate_record_hash(patient_data)
        insert_patient_data(connection, cursor, patient_data, 'admin')
    except ValueError as e:
        print(f"Error: {e}")
        
# Function to get the total number of records in the patient_info table
def get_total_record_count(cursor):
    query = "SELECT COUNT(*) FROM patient_info"
    cursor.execute(query)
    result = cursor.fetchone()
    return result['COUNT(*)'] if result else 0

# Retrieve patient data with role-based access control
def retrieve_patient_data(cursor, user_role):
    expected_count = get_total_record_count(cursor)

    query = "SELECT id, first_name, last_name, encrypted_gender, encrypted_age, key_gender, key_age, weight, height, health_history, record_hash FROM patient_info"
    cursor.execute(query)
    rows = cursor.fetchall()

    actual_count = len(rows)
    if actual_count != expected_count:
        print(f"Warning: Incomplete query results. Expected {expected_count}, but got {actual_count}")

    checksum = generate_checksum(rows)  # Calculate checksum for fetched records
    print("Checksum of retrieved records:", checksum)

    if user_role == 'admin':
        table = PrettyTable(["ID", "First Name", "Last Name", "Gender", "Age", "Weight", "Height", "Health History"])
    else:
        table = PrettyTable(["ID", "Gender", "Age", "Weight", "Height", "Health History"])

    for row in rows:
        # Decrypt gender and age for all users
        key_gender = base64.b64decode(row['key_gender']) if row['key_gender'] else None
        key_age = base64.b64decode(row['key_age']) if row['key_age'] else None

        decrypted_gender = decrypt_data_aes(row['encrypted_gender'], key_gender) if row['encrypted_gender'] and key_gender else "Unknown"
        decrypted_age = decrypt_data_aes(row['encrypted_age'], key_age) if row['encrypted_age'] and key_age else "Unknown"
        
        # Data Integrity Check
        if not verify_data_integrity(row, row['record_hash']):
            print(f"Data integrity issue detected for record ID: {row['id']}")

        if user_role == 'admin':
            table.add_row([
                row.get("id"),
                row.get("first_name"),
                row.get("last_name"),
                decrypted_gender,
                decrypted_age,
                row.get("weight"),
                row.get("height"),
                row.get("health_history")
            ])
        else:
            table.add_row([
                row.get("id"),
                decrypted_gender,
                decrypted_age,
                row.get("weight"),
                row.get("height"),
                row.get("health_history")
            ])

    print(table)

# %%
def main():
    mysql_password = getpass('Enter MySQL password: ')
    conn = pymysql.connect(
        host='localhost',
        user='root',
        password=mysql_password,
        charset='utf8mb4'
    )

    cursor = conn.cursor()
    cursor.execute("CREATE DATABASE IF NOT EXISTS healthdetailsdb")
    conn.commit()

    conn.close()

    # Now connect to the newly created database
    connection = pymysql.connect(
        host='localhost',
        user='root',
        password=mysql_password,
        database='healthdetailsdb',
        charset='utf8mb4',
        cursorclass=pymysql.cursors.DictCursor
    )

    authenticated_user = None
    user_role = None

    while True:
        if not authenticated_user:
            print("1. Login")
            print("2. Register")
            print("3. Test User Authentication (Admin Only)")
            print("4. Test Access Control (Admin Only)")
            print("5. Exit")
            choice = input("Enter choice: ")

            if choice == '1':
                username = input("Enter username: ")
                password = getpass("Enter password: ")
                if authenticate_user(connection.cursor(), username, password):
                    print("Login successful.")
                    authenticated_user = username
                    user_role = get_user_role(connection.cursor(), username)  # Getting the user's role
                else:
                    print("Login failed.")
            elif choice == '2':
                username = input("Enter new username: ")
                password = getpass("Enter new password: ")
                role = input("Enter role (admin/user): ").lower()
                register_user(connection, connection.cursor(), username, password, role)
            elif choice == '3':
                if authenticated_user and user_role == 'admin':
                    test_user_authentication(connection)
                else:
                    print("Admin access required.")

            elif choice == '4':
                if authenticated_user and user_role == 'admin':
                    test_access_control(connection)
                else:
                    print("Admin access required.")

            elif choice == '5':
                break

        else:
            print("\nLogged in as:", authenticated_user)
            print("4. View Patient Data")
            if user_role == 'admin':
                print("5. Add Patient Data")
            print("6. Logout")
            choice = input("Enter choice: ")

            if choice == '4':
                retrieve_patient_data(connection.cursor(), user_role)
            elif choice == '5' and user_role == 'admin':
                add_patient_data(connection, connection.cursor())
            elif choice == '6':
                authenticated_user = None
                user_role = None

    connection.close()

if __name__ == "__main__":
    main()
# Out:
# Enter MySQL password: ········
# 1. Login
# 2. Register
# 3. Test User Authentication (Admin Only)
# 4. Test Access Control (Admin Only)
# 5. Exit
# Enter choice: 1
# Enter username: AdminH
# Enter password: ········
# Login successful.
#
# Logged in as: AdminH
# 4. View Patient Data
# 5. Add Patient Data
# 6. Logout
# Enter choice: 4
# Checksum of retrieved records: 36591963379577042487165928895313754436767942701976340216986573450774994835700
# Data integrity issue detected for record ID: 101
# Data integrity issue detected for record ID: 102
# Data integrity issue detected for record ID: 103
# Data integrity issue detected for record ID: 104
# Data integrity issue detected for record ID: 105
# Data integrity issue detected for record ID: 106
# Data integrity issue detected for record ID: 107
# Data integrity issue detected for record ID: 108
# Data integrity issue detected for record ID: 109
# Data integrity issue detected for record ID: 110
# Data integrity issue detected for record ID: 111
# Data integrity issue detected for record ID: 112
# Data integrity issue detected for record ID: 113
# Data integrity issue detected for record ID: 114
# Data integrity issue detected for record ID: 115
# Data integrity issue detected for record ID: 116
# Data integrity issue detected for record ID: 117
# Data integrity issue detected for record ID: 118
# Data integrity issue detected for record ID: 119
# Data integrity issue detected for record ID: 120
# Data integrity issue detected for record ID: 121
# Data integrity issue detected for record ID: 122
# Data integrity issue detected for record ID: 123
# Data integrity issue detected for record ID: 124
# Data integrity issue detected for record ID: 125
# Data integrity issue detected for record ID: 126
# Data integrity issue detected for record ID: 127
# Data integrity issue detected for record ID: 128
# Data integrity issue detected for record ID: 129
# Data integrity issue detected for record ID: 130
# Data integrity issue detected for record ID: 131
# Data integrity issue detected for record ID: 132
# Data integrity issue detected for record ID: 133
# Data integrity issue detected for record ID: 134
# Data integrity issue detected for record ID: 135
# Data integrity issue detected for record ID: 136
# Data integrity issue detected for record ID: 137
# Data integrity issue detected for record ID: 138
# Data integrity issue detected for record ID: 139
# Data integrity issue detected for record ID: 140
# Data integrity issue detected for record ID: 141
# Data integrity issue detected for record ID: 142
# Data integrity issue detected for record ID: 143
# Data integrity issue detected for record ID: 144
# Data integrity issue detected for record ID: 145
# Data integrity issue detected for record ID: 146
# Data integrity issue detected for record ID: 147
# Data integrity issue detected for record ID: 148
# Data integrity issue detected for record ID: 149
# Data integrity issue detected for record ID: 150
# Data integrity issue detected for record ID: 151
# Data integrity issue detected for record ID: 152
# Data integrity issue detected for record ID: 153
# Data integrity issue detected for record ID: 154
# Data integrity issue detected for record ID: 155
# Data integrity issue detected for record ID: 156
# Data integrity issue detected for record ID: 157
# Data integrity issue detected for record ID: 158
# Data integrity issue detected for record ID: 159
# Data integrity issue detected for record ID: 160
# Data integrity issue detected for record ID: 161
# Data integrity issue detected for record ID: 162
# Data integrity issue detected for record ID: 163
# Data integrity issue detected for record ID: 164
# Data integrity issue detected for record ID: 165
# Data integrity issue detected for record ID: 166
# Data integrity issue detected for record ID: 167
# Data integrity issue detected for record ID: 168
# Data integrity issue detected for record ID: 169
# Data integrity issue detected for record ID: 170
# Data integrity issue detected for record ID: 171
# Data integrity issue detected for record ID: 172
# Data integrity issue detected for record ID: 173
# Data integrity issue detected for record ID: 174
# Data integrity issue detected for record ID: 175
# Data integrity issue detected for record ID: 176
# Data integrity issue detected for record ID: 177
# Data integrity issue detected for record ID: 178
# Data integrity issue detected for record ID: 179
# Data integrity issue detected for record ID: 180
# Data integrity issue detected for record ID: 181
# Data integrity issue detected for record ID: 182
# Data integrity issue detected for record ID: 183
# Data integrity issue detected for record ID: 184
# Data integrity issue detected for record ID: 185
# Data integrity issue detected for record ID: 186
# Data integrity issue detected for record ID: 187
# Data integrity issue detected for record ID: 188
# Data integrity issue detected for record ID: 189
# Data integrity issue detected for record ID: 190
# Data integrity issue detected for record ID: 191
# Data integrity issue detected for record ID: 192
# Data integrity issue detected for record ID: 193
# Data integrity issue detected for record ID: 194
# Data integrity issue detected for record ID: 195
# Data integrity issue detected for record ID: 196
# Data integrity issue detected for record ID: 197
# Data integrity issue detected for record ID: 198
# Data integrity issue detected for record ID: 199
# Data integrity issue detected for record ID: 200
# Data integrity issue detected for record ID: 201
# Data integrity issue detected for record ID: 202
# Data integrity issue detected for record ID: 203
# Data integrity issue detected for record ID: 204
# Data integrity issue detected for record ID: 205
# Data integrity issue detected for record ID: 206
# Data integrity issue detected for record ID: 207
# Data integrity issue detected for record ID: 208
# Data integrity issue detected for record ID: 209
# Data integrity issue detected for record ID: 210
# Data integrity issue detected for record ID: 211
# Data integrity issue detected for record ID: 212
# Data integrity issue detected for record ID: 213
# Data integrity issue detected for record ID: 214
# Data integrity issue detected for record ID: 215
# Data integrity issue detected for record ID: 216
# Data integrity issue detected for record ID: 217
# Data integrity issue detected for record ID: 218
# Data integrity issue detected for record ID: 219
# Data integrity issue detected for record ID: 220
# Data integrity issue detected for record ID: 221
# Data integrity issue detected for record ID: 222
# Data integrity issue detected for record ID: 223
# Data integrity issue detected for record ID: 224
# Data integrity issue detected for record ID: 225
# Data integrity issue detected for record ID: 226
# Data integrity issue detected for record ID: 227
# Data integrity issue detected for record ID: 228
# Data integrity issue detected for record ID: 229
# Data integrity issue detected for record ID: 230
# Data integrity issue detected for record ID: 231
# Data integrity issue detected for record ID: 232
# Data integrity issue detected for record ID: 233
# Data integrity issue detected for record ID: 234
# Data integrity issue detected for record ID: 235
# Data integrity issue detected for record ID: 236
# Data integrity issue detected for record ID: 237
# Data integrity issue detected for record ID: 238
# Data integrity issue detected for record ID: 239
# Data integrity issue detected for record ID: 240
# Data integrity issue detected for record ID: 241
# Data integrity issue detected for record ID: 242
# Data integrity issue detected for record ID: 243
# Data integrity issue detected for record ID: 244
# Data integrity issue detected for record ID: 245
# Data integrity issue detected for record ID: 246
# Data integrity issue detected for record ID: 247
# Data integrity issue detected for record ID: 248
# Data integrity issue detected for record ID: 249
# Data integrity issue detected for record ID: 250
# Data integrity issue detected for record ID: 251
# Data integrity issue detected for record ID: 252
# Data integrity issue detected for record ID: 253
# Data integrity issue detected for record ID: 254
# Data integrity issue detected for record ID: 255
# Data integrity issue detected for record ID: 256
# Data integrity issue detected for record ID: 257
# Data integrity issue detected for record ID: 258
# Data integrity issue detected for record ID: 259
# Data integrity issue detected for record ID: 260
# Data integrity issue detected for record ID: 261
# Data integrity issue detected for record ID: 262
# Data integrity issue detected for record ID: 263
# Data integrity issue detected for record ID: 264
# Data integrity issue detected for record ID: 265
# Data integrity issue detected for record ID: 266
# Data integrity issue detected for record ID: 267
# Data integrity issue detected for record ID: 268
# Data integrity issue detected for record ID: 269
# Data integrity issue detected for record ID: 270
# Data integrity issue detected for record ID: 271
# Data integrity issue detected for record ID: 272
# Data integrity issue detected for record ID: 273
# Data integrity issue detected for record ID: 274
# Data integrity issue detected for record ID: 275
# Data integrity issue detected for record ID: 276
# Data integrity issue detected for record ID: 277
# Data integrity issue detected for record ID: 278
# Data integrity issue detected for record ID: 279
# Data integrity issue detected for record ID: 280
# Data integrity issue detected for record ID: 281
# Data integrity issue detected for record ID: 282
# Data integrity issue detected for record ID: 283
# Data integrity issue detected for record ID: 284
# Data integrity issue detected for record ID: 285
# Data integrity issue detected for record ID: 286
# Data integrity issue detected for record ID: 287
# Data integrity issue detected for record ID: 288
# Data integrity issue detected for record ID: 289
# Data integrity issue detected for record ID: 290
# Data integrity issue detected for record ID: 291
# Data integrity issue detected for record ID: 292
# Data integrity issue detected for record ID: 293
# Data integrity issue detected for record ID: 294
# Data integrity issue detected for record ID: 295
# Data integrity issue detected for record ID: 296
# Data integrity issue detected for record ID: 297
# Data integrity issue detected for record ID: 298
# Data integrity issue detected for record ID: 299
# Data integrity issue detected for record ID: 300
# Data integrity issue detected for record ID: 301
# Data integrity issue detected for record ID: 302
# Data integrity issue detected for record ID: 303
# Data integrity issue detected for record ID: 304
# Data integrity issue detected for record ID: 305
# Data integrity issue detected for record ID: 306
# Data integrity issue detected for record ID: 307
# Data integrity issue detected for record ID: 308
# Data integrity issue detected for record ID: 309
# Data integrity issue detected for record ID: 310
# Data integrity issue detected for record ID: 311
# Data integrity issue detected for record ID: 312
# Data integrity issue detected for record ID: 313
# Data integrity issue detected for record ID: 314
# Data integrity issue detected for record ID: 315
# Data integrity issue detected for record ID: 316
# Data integrity issue detected for record ID: 317
# Data integrity issue detected for record ID: 318
# Data integrity issue detected for record ID: 319
# Data integrity issue detected for record ID: 320
# Data integrity issue detected for record ID: 321
# Data integrity issue detected for record ID: 322
# Data integrity issue detected for record ID: 323
# Data integrity issue detected for record ID: 324
# Data integrity issue detected for record ID: 325
# Data integrity issue detected for record ID: 326
# Data integrity issue detected for record ID: 327
# Data integrity issue detected for record ID: 328
# Data integrity issue detected for record ID: 329
# Data integrity issue detected for record ID: 330
# Data integrity issue detected for record ID: 331
# Data integrity issue detected for record ID: 332
# Data integrity issue detected for record ID: 333
# Data integrity issue detected for record ID: 334
# Data integrity issue detected for record ID: 335
# Data integrity issue detected for record ID: 336
# Data integrity issue detected for record ID: 337
# Data integrity issue detected for record ID: 338
# Data integrity issue detected for record ID: 339
# Data integrity issue detected for record ID: 340
# Data integrity issue detected for record ID: 341
# Data integrity issue detected for record ID: 342
# Data integrity issue detected for record ID: 343
# Data integrity issue detected for record ID: 344
# Data integrity issue detected for record ID: 345
# Data integrity issue detected for record ID: 346
# Data integrity issue detected for record ID: 347
# Data integrity issue detected for record ID: 348
# Data integrity issue detected for record ID: 349
# Data integrity issue detected for record ID: 350
# Data integrity issue detected for record ID: 351
# Data integrity issue detected for record ID: 352
# Data integrity issue detected for record ID: 353
# Data integrity issue detected for record ID: 354
# Data integrity issue detected for record ID: 355
# Data integrity issue detected for record ID: 356
# Data integrity issue detected for record ID: 357
# Data integrity issue detected for record ID: 358
# Data integrity issue detected for record ID: 359
# Data integrity issue detected for record ID: 360
# Data integrity issue detected for record ID: 361
# Data integrity issue detected for record ID: 362
# Data integrity issue detected for record ID: 363
# Data integrity issue detected for record ID: 364
# Data integrity issue detected for record ID: 365
# Data integrity issue detected for record ID: 366
# Data integrity issue detected for record ID: 367
# Data integrity issue detected for record ID: 368
# Data integrity issue detected for record ID: 369
# Data integrity issue detected for record ID: 370
# Data integrity issue detected for record ID: 371
# Data integrity issue detected for record ID: 372
# Data integrity issue detected for record ID: 373
# Data integrity issue detected for record ID: 374
# Data integrity issue detected for record ID: 375
# Data integrity issue detected for record ID: 376
# Data integrity issue detected for record ID: 377
# Data integrity issue detected for record ID: 378
# Data integrity issue detected for record ID: 379
# Data integrity issue detected for record ID: 380
# Data integrity issue detected for record ID: 381
# Data integrity issue detected for record ID: 382
# Data integrity issue detected for record ID: 383
# Data integrity issue detected for record ID: 384
# Data integrity issue detected for record ID: 385
# Data integrity issue detected for record ID: 386
# Data integrity issue detected for record ID: 387
# Data integrity issue detected for record ID: 388
# Data integrity issue detected for record ID: 389
# Data integrity issue detected for record ID: 390
# Data integrity issue detected for record ID: 391
# Data integrity issue detected for record ID: 392
# Data integrity issue detected for record ID: 393
# Data integrity issue detected for record ID: 394
# Data integrity issue detected for record ID: 395
# Data integrity issue detected for record ID: 396
# Data integrity issue detected for record ID: 397
# Data integrity issue detected for record ID: 398
# Data integrity issue detected for record ID: 399
# Data integrity issue detected for record ID: 400
# Data integrity issue detected for record ID: 401
# Data integrity issue detected for record ID: 402
# Data integrity issue detected for record ID: 403
# Data integrity issue detected for record ID: 404
# Data integrity issue detected for record ID: 405
# Data integrity issue detected for record ID: 406
# Data integrity issue detected for record ID: 407
# Data integrity issue detected for record ID: 409
# Data integrity issue detected for record ID: 410
# Data integrity issue detected for record ID: 412
# Data integrity issue detected for record ID: 416
# Data integrity issue detected for record ID: 420
# Data integrity issue detected for record ID: 424
# Data integrity issue detected for record ID: 428
# Data integrity issue detected for record ID: 432
# Data integrity issue detected for record ID: 436
# Data integrity issue detected for record ID: 440
# Data integrity issue detected for record ID: 442
# Data integrity issue detected for record ID: 444
# Data integrity issue detected for record ID: 446
# Data integrity issue detected for record ID: 447
# Data integrity issue detected for record ID: 448
# Data integrity issue detected for record ID: 452
# Data integrity issue detected for record ID: 453
# Data integrity issue detected for record ID: 455
# Data integrity issue detected for record ID: 456
# Data integrity issue detected for record ID: 458
# Data integrity issue detected for record ID: 459
# Data integrity issue detected for record ID: 460
# Data integrity issue detected for record ID: 461
# +-----+----------------------+---------------------+-------------+--------------+--------+--------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |  ID |      First Name      |      Last Name      |    Gender   |     Age      | Weight | Height |                                                                                     Health History                                                                                    |
# +-----+----------------------+---------------------+-------------+--------------+--------+--------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 101 |      Frederick       |        Gaines       |      1      |      47      | 100.0  | 154.06 |                                                                             Some create trade cause above.                                                                            |
# |     |                      |                     |             |              |        |        |                                                         Industry music best model collection. Do here official a key special.                                                         |
# | 102 |       Derrick        |        White        |      0      |      92      | 62.07  | 169.1  |                                                       Data leader open first. Actually produce offer benefit break station bag.                                                       |
# |     |                      |                     |             |              |        |        |                                             Sometimes impact lay second himself. Final response resource join law source. Must than skin.                                             |
# | 103 |        Julia         |       Francis       |      0      |      26      | 79.45  | 176.98 |         Student compare change something might including civil. Week station person some little particularly. Avoid garden professor information century point indicate serve.        |
# | 104 |         Erik         |      Alexander      |      1      |      81      | 66.05  | 178.9  |                                                      Computer film doctor election hear southern staff our. Six station anything.                                                     |
# |     |                      |                     |             |              |        |        |                                                       Thank shoulder although consumer probably people. Clear fly shoulder far.                                                       |
# | 105 |       Michael        |       Reynolds      |      1      |      2       | 65.89  | 169.94 |                               Section for successful down. Spend its computer well summer. Perform job doctor himself since popular coach relationship.                               |
# | 106 |         Amy          |         Lee         |      0      |      42      | 95.05  | 156.72 |                                                      Part nearly which nearly find ever. Speak gun reduce focus many we at deep.                                                      |
# |     |                      |                     |             |              |        |        |                                              Drop perform them attention election other sport. Discover while about mind daughter could.                                              |
# | 107 |       Virginia       |        Lopez        |      0      |      5       | 68.08  | 197.21 |                                                                     Interview civil ever lead character life high.                                                                    |
# |     |                      |                     |             |              |        |        |                                            Face ask owner above worry. Song reflect population occur notice help. West building help many.                                            |
# | 108 |       Brianna        |       Aguilar       |      1      |      80      | 80.93  | 179.65 |                                          Her rest nearly else. Necessary maybe long material way turn. Drug commercial drug thing where son.                                          |
# |     |                      |                     |             |              |        |        |                                             Perform only if always miss factor. His company use property. Reflect wish rather head group.                                             |
# | 109 |         Dawn         |       Matthews      |      1      |      56      | 64.43  | 175.41 |                                     Action kind at heart. Site like should safe role conference soon research. Dog suggest TV cause TV field back.                                    |
# | 110 |        Robert        |        Hughes       |      0      |      27      |  63.4  | 189.38 |                                                Only piece recognize technology character. Light reach various nothing model artist old.                                               |
# |     |                      |                     |             |              |        |        |                                                                           After process any so million ball.                                                                          |
# |     |                      |                     |             |              |        |        |                                                                            Whose husband indeed star idea.                                                                            |
# |     |                      |                     |             |              |        |        |                                                                       Rise cup interest first receive or thank.                                                                       |
# | 111 |        Donna         |        Murray       |      0      |      98      | 52.44  | 175.45 |                                                                    Executive in lot produce. Away baby job include.                                                                   |
# |     |                      |                     |             |              |        |        |                                            Simply traditional wonder one view. Project loss how range color picture. Seven let often water.                                           |
# | 112 |         Paul         |         Lee         |      0      |      62      | 69.02  | 177.48 |                                                  Ground protect despite push dark military these. Manage receive keep art important.                                                  |
# |     |                      |                     |             |              |        |        |                                                                     Not here range. Know page white purpose event.                                                                    |
# | 113 |       Jeffery        |        Holden       |      0      |      70      | 50.64  | 167.34 |                                        Close customer speech play. Candidate off know modern whose Mr. Beautiful class series also experience.                                        |
# | 114 |        Ashley        |       Bridges       |      1      |      78      | 72.35  | 185.07 |                                  Energy Republican ahead these remember give. Financial remain happen there soon set. Color brother bar though fear.                                  |
# | 115 |       Jeffrey        |       Collier       |      0      |      38      | 78.83  | 197.95 |                                                  Never record whom represent economy especially. Hope medical travel feeling listen.                                                  |
# |     |                      |                     |             |              |        |        |                                      Sing them hair face support first manage. Study street around into book. Rich skill sport white learn visit.                                     |
# | 116 |       Brandon        |        Walsh        |      1      |      71      | 94.22  | 157.59 |                                                    About professional treatment customer smile too bring. Effort form short piece.                                                    |
# |     |                      |                     |             |              |        |        |                                                   They determine within sign after past. Site drive event base. Different teach his.                                                  |
# | 117 |       Jennifer       |       Mullins       |      1      |      64      | 73.93  | 170.27 |                                                            Weight else impact coach subject value. Spring over close team.                                                            |
# |     |                      |                     |             |              |        |        |                               Government space imagine. Positive hit professional think reduce your ready. Trial per lead. Fire law answer measure his.                               |
# | 118 |        Rhonda        |       Williams      |      1      |      91      | 82.73  | 168.62 |                                                                         Concern risk camera simply recognize.                                                                         |
# |     |                      |                     |             |              |        |        |                                                     Lot soon can toward room year. Leave go who knowledge subject lay onto today.                                                     |
# |     |                      |                     |             |              |        |        |                                                                           Democrat during nature movie easy.                                                                          |
# | 119 |        Susan         |        Young        |      1      |      69      | 78.41  | 185.54 |                                          Political show fine what. Organization around though two wonder. Strong should eat focus technology.                                         |
# |     |                      |                     |             |              |        |        |                                                                Present until late industry. True life this turn thing.                                                                |
# | 120 |        Sarah         |       Stevens       |      1      |      80      | 95.17  | 161.16 |                                                         Nation sense dog all their report. Whether physical support character.                                                        |
# | 121 |         John         |         Page        |      0      |      36      | 82.73  | 168.35 |                                                              Thing provide approach dream she. Take explain within draw.                                                              |
# |     |                      |                     |             |              |        |        |                                       Threat energy big stuff drug line would. Ahead special soon green economic. Movement ask require response.                                      |
# | 122 |        James         |        Davis        |      1      |      22      | 86.54  | 165.74 |                                                             Whom box book field. Agency special decade since down brother.                                                            |
# |     |                      |                     |             |              |        |        |                                     Performance small enough central position manage modern. Professional red spring ball find body relationship.                                     |
# | 123 |        Joshua        |        Morgan       |      1      |      58      | 62.16  | 190.76 |                  Thus hospital institution pressure though fall small part. Community ground far meeting ten contain religious. Body of turn all season chair our by.                 |
# |     |                      |                     |             |              |        |        |                                                                               Sense cold role smile bit.                                                                              |
# | 124 |        Sandra        |        Martin       |      1      |      74      | 87.99  | 186.54 |                     Enter office happy instead night within. Skill boy during fine shoulder north building foreign. Power yard box dream anything door religious.                     |
# | 125 |       Patricia       |       Sullivan      |      0      |      10      | 72.69  | 161.08 |                                                          Movie decade quality step first. May range left way suddenly sense.                                                          |
# |     |                      |                     |             |              |        |        |                                             Public both then expert against foot similar. Entire guy key almost operation safe road bank.                                             |
# | 126 |        Chloe         |         Ware        |      1      |      30      | 56.77  | 177.67 |                                                                                Know but interview four.                                                                               |
# |     |                      |                     |             |              |        |        |                                           Control fly car standard morning. Once these fast single identify. Mrs themselves here north car.                                           |
# |     |                      |                     |             |              |        |        |                                                                            Plan summer list special often.                                                                            |
# | 127 |       Brandon        |       Johnson       |      0      |      82      | 75.68  | 150.87 |                                                    Full win whether defense teach. Hotel research ten rule. While blood serve help.                                                   |
# |     |                      |                     |             |              |        |        |                                                    Really capital bad leader. Color draw difference difference with way per stand.                                                    |
# | 128 |        David         |        Watts        |      0      |      72      | 60.94  | 160.82 |                                                         Real sense light local young. Along sport citizen. Color start house.                                                         |
# |     |                      |                     |             |              |        |        |                                     Thing yet check stuff. You can president than sort oil special history. Debate must against major race alone.                                     |
# | 129 |        Ashley        |         Lara        |      0      |      20      | 95.46  | 169.55 |                                                            Next finish impact common my. Also amount scene one while clear.                                                           |
# |     |                      |                     |             |              |        |        |                                                        Modern color chair campaign lot property. Work close environment night.                                                        |
# |     |                      |                     |             |              |        |        |                                                                  Dream character fire reveal action because decision.                                                                 |
# | 130 |        Austin        |         Byrd        |      1      |      66      | 82.51  | 188.47 |                                  Treatment heavy capital work popular possible. Thousand which listen method factor collection. Heart blue truth bad.                                 |
# |     |                      |                     |             |              |        |        |                                                           Explain let go whatever green. Tell fill others too anyone though.                                                          |
# | 131 |       Matthew        |        Taylor       |      0      |      13      | 99.35  | 195.02 |                                                         Particular attention continue collection put. No here much drop cell.                                                         |
# |     |                      |                     |             |              |        |        |                                                                          Start general economy every reality.                                                                         |
# | 132 |        Dustin        |        Martin       |      0      |      89      | 97.58  | 167.57 |                                                          Play close billion often who single. Analysis everybody war himself.                                                         |
# |     |                      |                     |             |              |        |        |                                      Rate blood condition big eight free car. Center risk relate trade. Interest admit key require officer east.                                      |
# | 133 |        Karen         |        Wright       |      1      |      36      |  91.9  | 190.9  |                                                         Design analysis door small community. Cover west capital vote public.                                                         |
# |     |                      |                     |             |              |        |        |                                                                             Season traditional term learn.                                                                            |
# | 134 |        Caleb         |       Salazar       |      1      |      10      | 70.18  | 168.23 |                                                             Tough will interesting brother. A skill themselves try either.                                                            |
# |     |                      |                     |             |              |        |        |                                          Entire everything price behind consumer tell improve. Until financial population want drug anything.                                         |
# | 135 |         Eric         |        Franco       |      0      |      13      | 78.38  | 187.21 |                                                   Writer accept talk. Think religious nor. Man lawyer list current ten information.                                                   |
# |     |                      |                     |             |              |        |        |                                               Actually drop respond on fine certain. Professional score approach different matter hand.                                               |
# | 136 |        Kayla         |        Lewis        |      0      |      44      | 56.15  | 198.67 |                                                                    Especially name watch. News keep economic road.                                                                    |
# |     |                      |                     |             |              |        |        |                                                                        Only report here. Respond sing position.                                                                       |
# |     |                      |                     |             |              |        |        |                                                 Husband chance black eye risk PM call. Entire owner into. College meeting yard right.                                                 |
# | 137 |       Kristen        |         Hunt        |      0      |      10      | 66.21  | 173.02 |                                                     Too marriage white approach everybody half. Pull find personal them fine art.                                                     |
# |     |                      |                     |             |              |        |        |                                                                   Sea newspaper discover compare record begin turn.                                                                   |
# | 138 |        James         |        Perez        |      0      |      56      | 84.21  | 153.32 |                                               Seem modern sometimes tend maintain. None ball loss front truth according provide rather.                                               |
# |     |                      |                     |             |              |        |        |                                         This score positive loss study least finish conference. Face teach party describe such bill join how.                                         |
# | 139 |         Amy          |        Jacobs       |      0      |      9       | 58.33  | 153.9  |              Entire wind answer two science reduce serious. Half result too suddenly could. Policy risk small recognize surface. Statement staff others sort cup section.             |
# | 140 |        Scott         |        Jones        |      0      |      61      | 51.69  | 170.25 |                             And join although minute ready fish. Single yourself continue involve most ability. Clear join office continue citizen study.                             |
# |     |                      |                     |             |              |        |        |                                                         Very dark nice safe ability tend. Real gas worker final meet born eat.                                                        |
# | 141 |        Daniel        |      Stevenson      |      0      |      6       | 86.07  | 185.59 |                  Head without positive building. Look thousand tend national shoulder challenge. Left have long series a. Return a thus special matter society this.                  |
# | 142 |        James         |        Newton       |      0      |      74      | 82.14  | 174.72 |                           Most student floor market box increase fear where. Happy tonight ago boy. Memory environment special factor per ready generation.                           |
# | 143 |        Blake         |        Rogers       |      1      |      10      | 68.15  | 179.53 |                                                              Star future us enjoy first purpose. Parent guess without a.                                                              |
# |     |                      |                     |             |              |        |        |                                                                              Group upon discussion stuff.                                                                             |
# |     |                      |                     |             |              |        |        |                                            Little alone me avoid language decade dog. Soon road strategy six around. Analysis amount near.                                            |
# | 144 |       Jonathan       |       Goodwin       |      0      |      30      | 50.48  | 172.35 |                          Direction child purpose remain all beyond. Boy thank establish adult successful. Head management officer describe other report fly.                          |
# | 145 |        Laura         |       Nichols       |      1      |      29      | 58.43  | 192.57 |                                         Carry evidence choice factor after them range. Miss perform similar become. Range fine available ask.                                         |
# | 146 |       Jessica        |        Brown        |      1      |      24      | 53.62  | 163.97 |                                                    Above take even successful house evening stand. Financial large statement mouth.                                                   |
# |     |                      |                     |             |              |        |        |                                                                                End American situation.                                                                                |
# |     |                      |                     |             |              |        |        |                                                                      Amount receive rise little. Member yeah tax.                                                                     |
# | 147 |        Dylan         |       Stewart       |      0      |      17      | 90.73  | 161.58 |                                    Foreign into own window everyone general use. And firm shake beyond onto your age. Range recent five be spring.                                    |
# |     |                      |                     |             |              |        |        |                                                                          Money top yet body after difference.                                                                         |
# | 148 |        Kevin         |       Leonard       |      0      |      91      | 90.61  | 192.39 |                                                   Man firm break receive development mission. Return option television clearly much.                                                  |
# |     |                      |                     |             |              |        |        |                                                          Music meeting boy sit item rich office. Someone sure wish property.                                                          |
# | 149 |         Ryan         |        Welch        |      0      |      0       | 70.97  | 173.11 |                                  Front break style choose down month design. Both Congress south arrive house when. Option about week sense article.                                  |
# |     |                      |                     |             |              |        |        |                                                                     Culture hand most question. Eat recognize bag.                                                                    |
# | 150 |        Rachel        |       Clements      |      0      |      89      | 86.95  | 155.14 |                                                            Realize must career physical. Inside police off. Fish long tax.                                                            |
# |     |                      |                     |             |              |        |        |                                                          Herself past while. Situation practice life he kitchen occur world.                                                          |
# | 151 |        Laurie        |      Armstrong      |      1      |      8       | 74.74  | 172.87 |                Daughter fire reduce use. Represent law chance fill reduce analysis. Blood compare company major degree. See glass drop main different region challenge.               |
# | 152 |         Lisa         |        Cortez       |      1      |      26      | 67.47  | 167.31 |                                                     Before rise sell usually defense election later reality. Protect debate part.                                                     |
# |     |                      |                     |             |              |        |        |                                            Fight take tell investment she capital. Down half resource. Also identify nearly movement safe.                                            |
# | 153 |      Christine       |       Williams      |      1      |      10      | 96.46  | 197.55 |                                             After begin site executive strategy statement. Budget our southern enter customer energy bank.                                            |
# |     |                      |                     |             |              |        |        |                                                                       Artist soldier reality million know good.                                                                       |
# |     |                      |                     |             |              |        |        |                                                                 Expert Republican also general us perform list dream.                                                                 |
# | 154 |         Ann          |        Cooper       |      1      |      95      | 50.22  | 195.21 |            Mind miss recent real production. Strong hand young stock. Want than history Republican tell sure reality organization. Campaign debate push professional play.            |
# | 155 |       Brandon        |         Reed        |      1      |      0       | 74.79  | 177.28 |                                              Each glass my evidence option. Defense little have. Executive black situation fish similar.                                              |
# | 156 |         Ryan         |        Fields       |      1      |      5       |  89.6  | 186.83 |                                            Spend protect clearly happy discussion have in push. Total film drop us join trouble low forget.                                           |
# | 157 |       Kimberly       |        Smith        |      1      |      6       | 60.26  | 194.41 |                                               Baby arm song notice feeling thought perform. Scene black themselves bill strong thousand.                                              |
# |     |                      |                     |             |              |        |        |                                                       Section group explain among. Later spend subject. Young toward room cause.                                                      |
# ...
# | 385 |      0      |      34      | 68.74  | 176.7  |                                                    East hear site main coach over choose discussion. Stuff song poor minute party.                                                    |
# |     |             |              |        |        |                                                 Hospital cut kind fly member stock. Themselves almost probably partner final must ago.                                                |
# | 386 |      0      |      28      | 75.12  | 197.51 |                                                        Turn letter free enter activity look. Sometimes billion thus bed itself.                                                       |
# |     |             |              |        |        |                                                             Employee throw bag natural explain. Develop small peace table.                                                            |
# | 387 |      1      |      68      |  50.4  | 157.07 |                                                                             Worker mission indicate money.                                                                            |
# |     |             |              |        |        |                                                   Marriage continue group positive often. Certainly throw note glass goal Congress.                                                   |
# | 388 |      0      |      22      | 84.76  | 163.32 |                                            House soon down. Attorney save sit line of move. Answer above young rather cause put close tree.                                           |
# |     |             |              |        |        |                                                                        Image foot family special garden chance.                                                                       |
# | 389 |      1      |      38      | 66.46  | 193.31 |                                                           Blood discuss run cup. Rest red everybody window important always.                                                          |
# | 390 |      0      |      31      | 99.19  | 168.2  |                                                                             Present truth dog even music.                                                                             |
# |     |             |              |        |        |                            Skill huge attack apply house never. Affect clear Congress notice happen. However feel without never family next today resource.                           |
# | 391 |      0      |      57      | 50.23  | 151.03 |                      Project of early technology maintain couple. Team far deep stage message magazine country. Letter already career fill smile prepare mission.                     |
# | 392 |      0      |      97      | 79.59  | 164.63 |                                                Government simple family. Better brother today oil growth worker. Concern natural cause.                                               |
# |     |             |              |        |        |                                                              Sense discuss model along. Sing reason road check statement.                                                             |
# |     |             |              |        |        |                                                                               A stop five business kid.                                                                               |
# | 393 |      0      |      55      |  56.9  | 199.8  |                                              Sell college success speech country fly figure your. Drive training material here activity.                                              |
# |     |             |              |        |        |                                            Difference call media worker. Section enough because these turn official. Book budget art admit.                                           |
# | 394 |      0      |      22      | 71.94  | 153.24 |                                                                                     Occur eat gas.                                                                                    |
# |     |             |              |        |        |                                                                                  Forget ahead arrive.                                                                                 |
# |     |             |              |        |        |                 Begin scientist economy last tell myself. Factor time peace community exist raise much. South town once per. Bit sit onto current note than southern.                 |
# | 395 |      1      |      63      | 99.41  | 164.55 |                                                                      Budget state college. Fund piece wall step.                                                                      |
# |     |             |              |        |        |                       Side hotel coach month generation know live food. Education man public lose affect against treat heart. Cup director true lawyer big hot.                       |
# | 396 |      1      |      38      | 91.94  | 157.61 |                                                        Fall sport energy side goal act event. Ever mention create environment.                                                        |
# |     |             |              |        |        |                                                Sure go guess prepare moment see home use. True heart remember performance market site.                                                |
# | 397 |      1      |      76      | 70.34  | 198.92 |                                                         End political stay cover method. Business range interesting discover.                                                         |
# |     |             |              |        |        |                                             Top difference activity thank better. Land effort analysis thank window rise number certainly.                                            |
# | 398 |      1      |      67      | 73.95  | 163.86 |                                                                         Fine measure the. Admit free how home.                                                                        |
# |     |             |              |        |        |                                                                     From whatever computer hear. Ever so will oil.                                                                    |
# |     |             |              |        |        |                                                                       Job training you finally probably itself.                                                                       |
# |     |             |              |        |        |                                                           Local stand day. Believe strategy family certain wait might white.                                                          |
# | 399 |      0      |      39      | 91.86  | 197.81 |                                         Card message type office agency at. Difference really dog. Loss beyond money manage here significant.                                         |
# | 400 |      0      |      29      | 52.62  | 155.32 |                                                   Author a everyone simply several with goal. List eat factor production move exist.                                                  |
# | 401 |      1      |      89      | 148.0  | 156.0  |                                                                                  test scenario obese                                                                                  |
# | 402 |   1******   |     30*      |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 403 |   1******   | 30********** |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 404 |   1*******  |   30*****    |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 405 |  1********* |   30*****    |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 406 |    1****    |  30*******   |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 407 |  1********  |   30*****    |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 409 |   1*******  |     35*      | 1650.0 | 165.0  |                                                                                         obese                                                                                         |
# | 410 |     1***    |   30******   |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 412 |     1**     |   30******   |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 416 |    1****    |   30******   |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 420 |    1*****   |     30*      |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 424 |     1***    |     30*      |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 428 |  1********  |  30*******   |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 432 | 1********** |     30*      |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 436 |    1*****   |  30*******   |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 440 |   1*******  |    30***     |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 442 | 1********** |     30*      |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 444 | 1********** |     30*      |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 446 |  1********  |    34***     | 100.0  | 165.0  |                                                                                      hafbhefkwah                                                                                      |
# | 447 |     1***    |   12******   |  13.0  | 1231.0 |                                                                                         jafja                                                                                         |
# | 448 |   1******   | 30********** |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 452 |  1********* | 11*********  | 123.0  |  75.0  |                                                                                          lean                                                                                         |
# | 453 | 1********** |  30********  |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 455 |  1********* |    23****    |  76.0  | 123.0  |                                                                                         dvdgtd                                                                                        |
# | 456 | 1********** |   30*****    |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 458 |  1********* | 30*********  |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 459 |   1******   |   30*****    | 650.0  | 170.0  |                                                                                      Test history                                                                                     |
# | 460 |     1***    |    30***     | 750.0  | 170.0  |                                                                                      Test history                                                                                     |
# | 461 |      1*     | 30*********  | 850.0  | 170.0  |                                                                                      Test history                                                                                     |
# | 462 |   1*******  |    12****    | 121.0  | 124.0  |                                                                                         vsfnsn                                                                                        |
# +-----+-------------+--------------+--------+--------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Logged in as: UserR1
# 4. View Patient Data
# 6. Logout
# Enter choice: 6
# 1. Login
# 2. Register
# 3. Test User Authentication (Admin Only)
# 4. Test Access Control (Admin Only)
# 5. Exit
# Enter choice: 3
# Admin access required.
# 1. Login
# 2. Register
# 3. Test User Authentication (Admin Only)
# 4. Test Access Control (Admin Only)
# 5. Exit
# Enter choice: 4
# Admin access required.
# 1. Login
# 2. Register
# 3. Test User Authentication (Admin Only)
# 4. Test Access Control (Admin Only)
# 5. Exit
# Enter choice: 5

# %%
#OVERALL SCENARIO TESTING FOR FINAL REPORT and as per REQUIREMENTS
def establish_connection():
    mysql_password = getpass('Enter MySQL password for testing: ')
    connection = pymysql.connect(
        host='localhost',
        user='root',
        password=mysql_password,
        database='healthdetailsdb',
        charset='utf8mb4',
        cursorclass=pymysql.cursors.DictCursor
    )
    return connection

def test_user_registration_and_login(connection):
    print("Testing User Registration and Login...")
    username = "test_user"
    password = "test_password"
    role = "user"

    # Register new user
    register_user(connection, connection.cursor(), username, password, role)

    # Attempt correct login
    assert authenticate_user(connection.cursor(), username, password), "Login with correct password failed."

    # Attempt incorrect login
    assert not authenticate_user(connection.cursor(), username, "wrong_password"), "Login with incorrect password succeeded."

    print("User Registration and Login Test Passed.")

def test_access_control(connection):
    print("Testing Access Control...")
    admin_username = "admin_user"
    admin_password = "admin_password"
    user_username = "regular_user"
    user_password = "user_password"

    # Register admin and user
    register_user(connection, connection.cursor(), admin_username, admin_password, "admin")
    register_user(connection, connection.cursor(), user_username, user_password, "user")

    # Verify admin can see all fields
    if authenticate_user(connection.cursor(), admin_username, admin_password):
        admin_role = get_user_role(connection.cursor(), admin_username)
        retrieve_patient_data(connection.cursor(), admin_role)

    # Verify user cannot see first and last name
    if authenticate_user(connection.cursor(), user_username, user_password):
        user_role = get_user_role(connection.cursor(), user_username)
        retrieve_patient_data(connection.cursor(), user_role)

    print("Access Control Test Passed.")

def test_data_integrity(connection):
    print("Testing Data Integrity...")
    cursor = connection.cursor()

    # Select and print the original record
    cursor.execute("SELECT * FROM patient_info WHERE id = 101")
    original_record = cursor.fetchone()
    print("Original Record:", original_record)

    # Modify the record (e.g., change the weight)
    new_weight = 100.00  # Example new weight
    cursor.execute("UPDATE patient_info SET weight = %s WHERE id = 101", (new_weight,))
    connection.commit()

    # Recalculate and update the hash for the modified record
    modified_record = original_record.copy()
    modified_record['weight'] = new_weight
    modified_hash = generate_record_hash(modified_record)
    cursor.execute("UPDATE patient_info SET record_hash = %s WHERE id = 101", (modified_hash,))
    connection.commit()

    # Retrieve and print the modified record
    cursor.execute("SELECT * FROM patient_info WHERE id = 101")
    updated_record = cursor.fetchone()
    print("Modified Record:", updated_record)

    # Check data integrity (expected to fail as the record has been modified)
    assert not verify_data_integrity(updated_record, updated_record['record_hash']), "Data integrity test failed: Modification not detected"

    print("Data Integrity Test Passed.")

def test_data_confidentiality(connection):
    print("Testing Data Confidentiality...")
    cursor = connection.cursor()

    # Retrieve a record and check if gender and age are encrypted
    cursor.execute("SELECT encrypted_gender, encrypted_age, key_gender, key_age FROM patient_info WHERE id = 101")
    record = cursor.fetchone()
    
    encrypted_gender = record['encrypted_gender']
    encrypted_age = record['encrypted_age']
    key_gender = base64.b64decode(record['key_gender'])
    key_age = base64.b64decode(record['key_age'])

    # Check that values are encrypted
    assert encrypted_gender is not None and encrypted_age is not None, "Data confidentiality test failed: Gender or Age not encrypted"

    # Decrypt and check values
    decrypted_gender = decrypt_data_aes(encrypted_gender, key_gender)
    decrypted_age = decrypt_data_aes(encrypted_age, key_age)
    
    assert decrypted_gender is not None and decrypted_age is not None, "Data confidentiality test failed: Decryption error"

    print("Data Confidentiality Test Passed.")
    
if __name__ == "__main__":
    connection = establish_connection()

    # Add test functions here
    test_user_registration_and_login(connection)
    test_access_control(connection)
    test_data_integrity(connection)
    test_data_confidentiality(connection)

    connection.close()
# Out:
# Enter MySQL password for testing: ········
# Testing User Registration and Login...
# Username already exists.
# User Registration and Login Test Passed.
# Testing Access Control...
# Username already exists.
# Username already exists.
# Checksum of retrieved records: 3897764602473693014363106425889228458420450783333498583202162250394541373830
# Data integrity issue detected for record ID: 101
# Data integrity issue detected for record ID: 102
# Data integrity issue detected for record ID: 103
# Data integrity issue detected for record ID: 104
# Data integrity issue detected for record ID: 105
# Data integrity issue detected for record ID: 106
# Data integrity issue detected for record ID: 107
# Data integrity issue detected for record ID: 108
# Data integrity issue detected for record ID: 109
# Data integrity issue detected for record ID: 110
# Data integrity issue detected for record ID: 111
# Data integrity issue detected for record ID: 112
# Data integrity issue detected for record ID: 113
# Data integrity issue detected for record ID: 114
# Data integrity issue detected for record ID: 115
# Data integrity issue detected for record ID: 116
# Data integrity issue detected for record ID: 117
# Data integrity issue detected for record ID: 118
# Data integrity issue detected for record ID: 119
# Data integrity issue detected for record ID: 120
# Data integrity issue detected for record ID: 121
# Data integrity issue detected for record ID: 122
# Data integrity issue detected for record ID: 123
# Data integrity issue detected for record ID: 124
# Data integrity issue detected for record ID: 125
# Data integrity issue detected for record ID: 126
# Data integrity issue detected for record ID: 127
# Data integrity issue detected for record ID: 128
# Data integrity issue detected for record ID: 129
# Data integrity issue detected for record ID: 130
# Data integrity issue detected for record ID: 131
# Data integrity issue detected for record ID: 132
# Data integrity issue detected for record ID: 133
# Data integrity issue detected for record ID: 134
# Data integrity issue detected for record ID: 135
# Data integrity issue detected for record ID: 136
# Data integrity issue detected for record ID: 137
# Data integrity issue detected for record ID: 138
# Data integrity issue detected for record ID: 139
# Data integrity issue detected for record ID: 140
# Data integrity issue detected for record ID: 141
# Data integrity issue detected for record ID: 142
# Data integrity issue detected for record ID: 143
# Data integrity issue detected for record ID: 144
# Data integrity issue detected for record ID: 145
# Data integrity issue detected for record ID: 146
# Data integrity issue detected for record ID: 147
# Data integrity issue detected for record ID: 148
# Data integrity issue detected for record ID: 149
# Data integrity issue detected for record ID: 150
# Data integrity issue detected for record ID: 151
# Data integrity issue detected for record ID: 152
# Data integrity issue detected for record ID: 153
# Data integrity issue detected for record ID: 154
# Data integrity issue detected for record ID: 155
# Data integrity issue detected for record ID: 156
# Data integrity issue detected for record ID: 157
# Data integrity issue detected for record ID: 158
# Data integrity issue detected for record ID: 159
# Data integrity issue detected for record ID: 160
# Data integrity issue detected for record ID: 161
# Data integrity issue detected for record ID: 162
# Data integrity issue detected for record ID: 163
# Data integrity issue detected for record ID: 164
# Data integrity issue detected for record ID: 165
# Data integrity issue detected for record ID: 166
# Data integrity issue detected for record ID: 167
# Data integrity issue detected for record ID: 168
# Data integrity issue detected for record ID: 169
# Data integrity issue detected for record ID: 170
# Data integrity issue detected for record ID: 171
# Data integrity issue detected for record ID: 172
# Data integrity issue detected for record ID: 173
# Data integrity issue detected for record ID: 174
# Data integrity issue detected for record ID: 175
# Data integrity issue detected for record ID: 176
# Data integrity issue detected for record ID: 177
# Data integrity issue detected for record ID: 178
# Data integrity issue detected for record ID: 179
# Data integrity issue detected for record ID: 180
# Data integrity issue detected for record ID: 181
# Data integrity issue detected for record ID: 182
# Data integrity issue detected for record ID: 183
# Data integrity issue detected for record ID: 184
# Data integrity issue detected for record ID: 185
# Data integrity issue detected for record ID: 186
# Data integrity issue detected for record ID: 187
# Data integrity issue detected for record ID: 188
# Data integrity issue detected for record ID: 189
# Data integrity issue detected for record ID: 190
# Data integrity issue detected for record ID: 191
# Data integrity issue detected for record ID: 192
# Data integrity issue detected for record ID: 193
# Data integrity issue detected for record ID: 194
# Data integrity issue detected for record ID: 195
# Data integrity issue detected for record ID: 196
# Data integrity issue detected for record ID: 197
# Data integrity issue detected for record ID: 198
# Data integrity issue detected for record ID: 199
# Data integrity issue detected for record ID: 200
# Data integrity issue detected for record ID: 201
# Data integrity issue detected for record ID: 202
# Data integrity issue detected for record ID: 203
# Data integrity issue detected for record ID: 204
# Data integrity issue detected for record ID: 205
# Data integrity issue detected for record ID: 206
# Data integrity issue detected for record ID: 207
# Data integrity issue detected for record ID: 208
# Data integrity issue detected for record ID: 209
# Data integrity issue detected for record ID: 210
# Data integrity issue detected for record ID: 211
# Data integrity issue detected for record ID: 212
# Data integrity issue detected for record ID: 213
# Data integrity issue detected for record ID: 214
# Data integrity issue detected for record ID: 215
# Data integrity issue detected for record ID: 216
# Data integrity issue detected for record ID: 217
# Data integrity issue detected for record ID: 218
# Data integrity issue detected for record ID: 219
# Data integrity issue detected for record ID: 220
# Data integrity issue detected for record ID: 221
# Data integrity issue detected for record ID: 222
# Data integrity issue detected for record ID: 223
# Data integrity issue detected for record ID: 224
# Data integrity issue detected for record ID: 225
# Data integrity issue detected for record ID: 226
# Data integrity issue detected for record ID: 227
# Data integrity issue detected for record ID: 228
# Data integrity issue detected for record ID: 229
# Data integrity issue detected for record ID: 230
# Data integrity issue detected for record ID: 231
# Data integrity issue detected for record ID: 232
# Data integrity issue detected for record ID: 233
# Data integrity issue detected for record ID: 234
# Data integrity issue detected for record ID: 235
# Data integrity issue detected for record ID: 236
# Data integrity issue detected for record ID: 237
# Data integrity issue detected for record ID: 238
# Data integrity issue detected for record ID: 239
# Data integrity issue detected for record ID: 240
# Data integrity issue detected for record ID: 241
# Data integrity issue detected for record ID: 242
# Data integrity issue detected for record ID: 243
# Data integrity issue detected for record ID: 244
# Data integrity issue detected for record ID: 245
# Data integrity issue detected for record ID: 246
# Data integrity issue detected for record ID: 247
# Data integrity issue detected for record ID: 248
# Data integrity issue detected for record ID: 249
# Data integrity issue detected for record ID: 250
# Data integrity issue detected for record ID: 251
# Data integrity issue detected for record ID: 252
# Data integrity issue detected for record ID: 253
# Data integrity issue detected for record ID: 254
# Data integrity issue detected for record ID: 255
# Data integrity issue detected for record ID: 256
# Data integrity issue detected for record ID: 257
# Data integrity issue detected for record ID: 258
# Data integrity issue detected for record ID: 259
# Data integrity issue detected for record ID: 260
# Data integrity issue detected for record ID: 261
# Data integrity issue detected for record ID: 262
# Data integrity issue detected for record ID: 263
# Data integrity issue detected for record ID: 264
# Data integrity issue detected for record ID: 265
# Data integrity issue detected for record ID: 266
# Data integrity issue detected for record ID: 267
# Data integrity issue detected for record ID: 268
# Data integrity issue detected for record ID: 269
# Data integrity issue detected for record ID: 270
# Data integrity issue detected for record ID: 271
# Data integrity issue detected for record ID: 272
# Data integrity issue detected for record ID: 273
# Data integrity issue detected for record ID: 274
# Data integrity issue detected for record ID: 275
# Data integrity issue detected for record ID: 276
# Data integrity issue detected for record ID: 277
# Data integrity issue detected for record ID: 278
# Data integrity issue detected for record ID: 279
# Data integrity issue detected for record ID: 280
# Data integrity issue detected for record ID: 281
# Data integrity issue detected for record ID: 282
# Data integrity issue detected for record ID: 283
# Data integrity issue detected for record ID: 284
# Data integrity issue detected for record ID: 285
# Data integrity issue detected for record ID: 286
# Data integrity issue detected for record ID: 287
# Data integrity issue detected for record ID: 288
# Data integrity issue detected for record ID: 289
# Data integrity issue detected for record ID: 290
# Data integrity issue detected for record ID: 291
# Data integrity issue detected for record ID: 292
# Data integrity issue detected for record ID: 293
# Data integrity issue detected for record ID: 294
# Data integrity issue detected for record ID: 295
# Data integrity issue detected for record ID: 296
# Data integrity issue detected for record ID: 297
# Data integrity issue detected for record ID: 298
# Data integrity issue detected for record ID: 299
# Data integrity issue detected for record ID: 300
# Data integrity issue detected for record ID: 301
# Data integrity issue detected for record ID: 302
# Data integrity issue detected for record ID: 303
# Data integrity issue detected for record ID: 304
# Data integrity issue detected for record ID: 305
# Data integrity issue detected for record ID: 306
# Data integrity issue detected for record ID: 307
# Data integrity issue detected for record ID: 308
# Data integrity issue detected for record ID: 309
# Data integrity issue detected for record ID: 310
# Data integrity issue detected for record ID: 311
# Data integrity issue detected for record ID: 312
# Data integrity issue detected for record ID: 313
# Data integrity issue detected for record ID: 314
# Data integrity issue detected for record ID: 315
# Data integrity issue detected for record ID: 316
# Data integrity issue detected for record ID: 317
# Data integrity issue detected for record ID: 318
# Data integrity issue detected for record ID: 319
# Data integrity issue detected for record ID: 320
# Data integrity issue detected for record ID: 321
# Data integrity issue detected for record ID: 322
# Data integrity issue detected for record ID: 323
# Data integrity issue detected for record ID: 324
# Data integrity issue detected for record ID: 325
# Data integrity issue detected for record ID: 326
# Data integrity issue detected for record ID: 327
# Data integrity issue detected for record ID: 328
# Data integrity issue detected for record ID: 329
# Data integrity issue detected for record ID: 330
# Data integrity issue detected for record ID: 331
# Data integrity issue detected for record ID: 332
# Data integrity issue detected for record ID: 333
# Data integrity issue detected for record ID: 334
# Data integrity issue detected for record ID: 335
# Data integrity issue detected for record ID: 336
# Data integrity issue detected for record ID: 337
# Data integrity issue detected for record ID: 338
# Data integrity issue detected for record ID: 339
# Data integrity issue detected for record ID: 340
# Data integrity issue detected for record ID: 341
# Data integrity issue detected for record ID: 342
# Data integrity issue detected for record ID: 343
# Data integrity issue detected for record ID: 344
# Data integrity issue detected for record ID: 345
# Data integrity issue detected for record ID: 346
# Data integrity issue detected for record ID: 347
# Data integrity issue detected for record ID: 348
# Data integrity issue detected for record ID: 349
# Data integrity issue detected for record ID: 350
# Data integrity issue detected for record ID: 351
# Data integrity issue detected for record ID: 352
# Data integrity issue detected for record ID: 353
# Data integrity issue detected for record ID: 354
# Data integrity issue detected for record ID: 355
# Data integrity issue detected for record ID: 356
# Data integrity issue detected for record ID: 357
# Data integrity issue detected for record ID: 358
# Data integrity issue detected for record ID: 359
# Data integrity issue detected for record ID: 360
# Data integrity issue detected for record ID: 361
# Data integrity issue detected for record ID: 362
# Data integrity issue detected for record ID: 363
# Data integrity issue detected for record ID: 364
# Data integrity issue detected for record ID: 365
# Data integrity issue detected for record ID: 366
# Data integrity issue detected for record ID: 367
# Data integrity issue detected for record ID: 368
# Data integrity issue detected for record ID: 369
# Data integrity issue detected for record ID: 370
# Data integrity issue detected for record ID: 371
# Data integrity issue detected for record ID: 372
# Data integrity issue detected for record ID: 373
# Data integrity issue detected for record ID: 374
# Data integrity issue detected for record ID: 375
# Data integrity issue detected for record ID: 376
# Data integrity issue detected for record ID: 377
# Data integrity issue detected for record ID: 378
# Data integrity issue detected for record ID: 379
# Data integrity issue detected for record ID: 380
# Data integrity issue detected for record ID: 381
# Data integrity issue detected for record ID: 382
# Data integrity issue detected for record ID: 383
# Data integrity issue detected for record ID: 384
# Data integrity issue detected for record ID: 385
# Data integrity issue detected for record ID: 386
# Data integrity issue detected for record ID: 387
# Data integrity issue detected for record ID: 388
# Data integrity issue detected for record ID: 389
# Data integrity issue detected for record ID: 390
# Data integrity issue detected for record ID: 391
# Data integrity issue detected for record ID: 392
# Data integrity issue detected for record ID: 393
# Data integrity issue detected for record ID: 394
# Data integrity issue detected for record ID: 395
# Data integrity issue detected for record ID: 396
# Data integrity issue detected for record ID: 397
# Data integrity issue detected for record ID: 398
# Data integrity issue detected for record ID: 399
# Data integrity issue detected for record ID: 400
# Data integrity issue detected for record ID: 401
# Data integrity issue detected for record ID: 402
# Data integrity issue detected for record ID: 403
# Data integrity issue detected for record ID: 404
# Data integrity issue detected for record ID: 405
# Data integrity issue detected for record ID: 406
# Data integrity issue detected for record ID: 407
# Data integrity issue detected for record ID: 409
# Data integrity issue detected for record ID: 410
# Data integrity issue detected for record ID: 412
# Data integrity issue detected for record ID: 416
# Data integrity issue detected for record ID: 420
# Data integrity issue detected for record ID: 424
# Data integrity issue detected for record ID: 428
# Data integrity issue detected for record ID: 432
# Data integrity issue detected for record ID: 436
# Data integrity issue detected for record ID: 440
# Data integrity issue detected for record ID: 442
# Data integrity issue detected for record ID: 444
# Data integrity issue detected for record ID: 446
# Data integrity issue detected for record ID: 447
# Data integrity issue detected for record ID: 448
# Data integrity issue detected for record ID: 452
# Data integrity issue detected for record ID: 453
# Data integrity issue detected for record ID: 455
# Data integrity issue detected for record ID: 456
# Data integrity issue detected for record ID: 458
# Data integrity issue detected for record ID: 459
# Data integrity issue detected for record ID: 460
# Data integrity issue detected for record ID: 461
# Data integrity issue detected for record ID: 462
# +-----+----------------------+---------------------+-------------+--------------+--------+--------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |  ID |      First Name      |      Last Name      |    Gender   |     Age      | Weight | Height |                                                                                     Health History                                                                                    |
# +-----+----------------------+---------------------+-------------+--------------+--------+--------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 101 |      Frederick       |        Gaines       |      1      |      47      | 100.0  | 154.06 |                                                                             Some create trade cause above.                                                                            |
# |     |                      |                     |             |              |        |        |                                                         Industry music best model collection. Do here official a key special.                                                         |
# | 102 |       Derrick        |        White        |      0      |      92      | 62.07  | 169.1  |                                                       Data leader open first. Actually produce offer benefit break station bag.                                                       |
# |     |                      |                     |             |              |        |        |                                             Sometimes impact lay second himself. Final response resource join law source. Must than skin.                                             |
# | 103 |        Julia         |       Francis       |      0      |      26      | 79.45  | 176.98 |         Student compare change something might including civil. Week station person some little particularly. Avoid garden professor information century point indicate serve.        |
# | 104 |         Erik         |      Alexander      |      1      |      81      | 66.05  | 178.9  |                                                      Computer film doctor election hear southern staff our. Six station anything.                                                     |
# |     |                      |                     |             |              |        |        |                                                       Thank shoulder although consumer probably people. Clear fly shoulder far.                                                       |
# | 105 |       Michael        |       Reynolds      |      1      |      2       | 65.89  | 169.94 |                               Section for successful down. Spend its computer well summer. Perform job doctor himself since popular coach relationship.                               |
# | 106 |         Amy          |         Lee         |      0      |      42      | 95.05  | 156.72 |                                                      Part nearly which nearly find ever. Speak gun reduce focus many we at deep.                                                      |
# |     |                      |                     |             |              |        |        |                                              Drop perform them attention election other sport. Discover while about mind daughter could.                                              |
# | 107 |       Virginia       |        Lopez        |      0      |      5       | 68.08  | 197.21 |                                                                     Interview civil ever lead character life high.                                                                    |
# |     |                      |                     |             |              |        |        |                                            Face ask owner above worry. Song reflect population occur notice help. West building help many.                                            |
# | 108 |       Brianna        |       Aguilar       |      1      |      80      | 80.93  | 179.65 |                                          Her rest nearly else. Necessary maybe long material way turn. Drug commercial drug thing where son.                                          |
# |     |                      |                     |             |              |        |        |                                             Perform only if always miss factor. His company use property. Reflect wish rather head group.                                             |
# | 109 |         Dawn         |       Matthews      |      1      |      56      | 64.43  | 175.41 |                                     Action kind at heart. Site like should safe role conference soon research. Dog suggest TV cause TV field back.                                    |
# | 110 |        Robert        |        Hughes       |      0      |      27      |  63.4  | 189.38 |                                                Only piece recognize technology character. Light reach various nothing model artist old.                                               |
# |     |                      |                     |             |              |        |        |                                                                           After process any so million ball.                                                                          |
# |     |                      |                     |             |              |        |        |                                                                            Whose husband indeed star idea.                                                                            |
# |     |                      |                     |             |              |        |        |                                                                       Rise cup interest first receive or thank.                                                                       |
# | 111 |        Donna         |        Murray       |      0      |      98      | 52.44  | 175.45 |                                                                    Executive in lot produce. Away baby job include.                                                                   |
# |     |                      |                     |             |              |        |        |                                            Simply traditional wonder one view. Project loss how range color picture. Seven let often water.                                           |
# | 112 |         Paul         |         Lee         |      0      |      62      | 69.02  | 177.48 |                                                  Ground protect despite push dark military these. Manage receive keep art important.                                                  |
# |     |                      |                     |             |              |        |        |                                                                     Not here range. Know page white purpose event.                                                                    |
# | 113 |       Jeffery        |        Holden       |      0      |      70      | 50.64  | 167.34 |                                        Close customer speech play. Candidate off know modern whose Mr. Beautiful class series also experience.                                        |
# | 114 |        Ashley        |       Bridges       |      1      |      78      | 72.35  | 185.07 |                                  Energy Republican ahead these remember give. Financial remain happen there soon set. Color brother bar though fear.                                  |
# | 115 |       Jeffrey        |       Collier       |      0      |      38      | 78.83  | 197.95 |                                                  Never record whom represent economy especially. Hope medical travel feeling listen.                                                  |
# |     |                      |                     |             |              |        |        |                                      Sing them hair face support first manage. Study street around into book. Rich skill sport white learn visit.                                     |
# | 116 |       Brandon        |        Walsh        |      1      |      71      | 94.22  | 157.59 |                                                    About professional treatment customer smile too bring. Effort form short piece.                                                    |
# |     |                      |                     |             |              |        |        |                                                   They determine within sign after past. Site drive event base. Different teach his.                                                  |
# | 117 |       Jennifer       |       Mullins       |      1      |      64      | 73.93  | 170.27 |                                                            Weight else impact coach subject value. Spring over close team.                                                            |
# |     |                      |                     |             |              |        |        |                               Government space imagine. Positive hit professional think reduce your ready. Trial per lead. Fire law answer measure his.                               |
# | 118 |        Rhonda        |       Williams      |      1      |      91      | 82.73  | 168.62 |                                                                         Concern risk camera simply recognize.                                                                         |
# |     |                      |                     |             |              |        |        |                                                     Lot soon can toward room year. Leave go who knowledge subject lay onto today.                                                     |
# |     |                      |                     |             |              |        |        |                                                                           Democrat during nature movie easy.                                                                          |
# | 119 |        Susan         |        Young        |      1      |      69      | 78.41  | 185.54 |                                          Political show fine what. Organization around though two wonder. Strong should eat focus technology.                                         |
# |     |                      |                     |             |              |        |        |                                                                Present until late industry. True life this turn thing.                                                                |
# | 120 |        Sarah         |       Stevens       |      1      |      80      | 95.17  | 161.16 |                                                         Nation sense dog all their report. Whether physical support character.                                                        |
# | 121 |         John         |         Page        |      0      |      36      | 82.73  | 168.35 |                                                              Thing provide approach dream she. Take explain within draw.                                                              |
# |     |                      |                     |             |              |        |        |                                       Threat energy big stuff drug line would. Ahead special soon green economic. Movement ask require response.                                      |
# | 122 |        James         |        Davis        |      1      |      22      | 86.54  | 165.74 |                                                             Whom box book field. Agency special decade since down brother.                                                            |
# |     |                      |                     |             |              |        |        |                                     Performance small enough central position manage modern. Professional red spring ball find body relationship.                                     |
# | 123 |        Joshua        |        Morgan       |      1      |      58      | 62.16  | 190.76 |                  Thus hospital institution pressure though fall small part. Community ground far meeting ten contain religious. Body of turn all season chair our by.                 |
# |     |                      |                     |             |              |        |        |                                                                               Sense cold role smile bit.                                                                              |
# | 124 |        Sandra        |        Martin       |      1      |      74      | 87.99  | 186.54 |                     Enter office happy instead night within. Skill boy during fine shoulder north building foreign. Power yard box dream anything door religious.                     |
# | 125 |       Patricia       |       Sullivan      |      0      |      10      | 72.69  | 161.08 |                                                          Movie decade quality step first. May range left way suddenly sense.                                                          |
# |     |                      |                     |             |              |        |        |                                             Public both then expert against foot similar. Entire guy key almost operation safe road bank.                                             |
# | 126 |        Chloe         |         Ware        |      1      |      30      | 56.77  | 177.67 |                                                                                Know but interview four.                                                                               |
# |     |                      |                     |             |              |        |        |                                           Control fly car standard morning. Once these fast single identify. Mrs themselves here north car.                                           |
# |     |                      |                     |             |              |        |        |                                                                            Plan summer list special often.                                                                            |
# | 127 |       Brandon        |       Johnson       |      0      |      82      | 75.68  | 150.87 |                                                    Full win whether defense teach. Hotel research ten rule. While blood serve help.                                                   |
# |     |                      |                     |             |              |        |        |                                                    Really capital bad leader. Color draw difference difference with way per stand.                                                    |
# | 128 |        David         |        Watts        |      0      |      72      | 60.94  | 160.82 |                                                         Real sense light local young. Along sport citizen. Color start house.                                                         |
# |     |                      |                     |             |              |        |        |                                     Thing yet check stuff. You can president than sort oil special history. Debate must against major race alone.                                     |
# | 129 |        Ashley        |         Lara        |      0      |      20      | 95.46  | 169.55 |                                                            Next finish impact common my. Also amount scene one while clear.                                                           |
# |     |                      |                     |             |              |        |        |                                                        Modern color chair campaign lot property. Work close environment night.                                                        |
# |     |                      |                     |             |              |        |        |                                                                  Dream character fire reveal action because decision.                                                                 |
# | 130 |        Austin        |         Byrd        |      1      |      66      | 82.51  | 188.47 |                                  Treatment heavy capital work popular possible. Thousand which listen method factor collection. Heart blue truth bad.                                 |
# |     |                      |                     |             |              |        |        |                                                           Explain let go whatever green. Tell fill others too anyone though.                                                          |
# | 131 |       Matthew        |        Taylor       |      0      |      13      | 99.35  | 195.02 |                                                         Particular attention continue collection put. No here much drop cell.                                                         |
# |     |                      |                     |             |              |        |        |                                                                          Start general economy every reality.                                                                         |
# | 132 |        Dustin        |        Martin       |      0      |      89      | 97.58  | 167.57 |                                                          Play close billion often who single. Analysis everybody war himself.                                                         |
# |     |                      |                     |             |              |        |        |                                      Rate blood condition big eight free car. Center risk relate trade. Interest admit key require officer east.                                      |
# | 133 |        Karen         |        Wright       |      1      |      36      |  91.9  | 190.9  |                                                         Design analysis door small community. Cover west capital vote public.                                                         |
# |     |                      |                     |             |              |        |        |                                                                             Season traditional term learn.                                                                            |
# | 134 |        Caleb         |       Salazar       |      1      |      10      | 70.18  | 168.23 |                                                             Tough will interesting brother. A skill themselves try either.                                                            |
# |     |                      |                     |             |              |        |        |                                          Entire everything price behind consumer tell improve. Until financial population want drug anything.                                         |
# | 135 |         Eric         |        Franco       |      0      |      13      | 78.38  | 187.21 |                                                   Writer accept talk. Think religious nor. Man lawyer list current ten information.                                                   |
# |     |                      |                     |             |              |        |        |                                               Actually drop respond on fine certain. Professional score approach different matter hand.                                               |
# | 136 |        Kayla         |        Lewis        |      0      |      44      | 56.15  | 198.67 |                                                                    Especially name watch. News keep economic road.                                                                    |
# |     |                      |                     |             |              |        |        |                                                                        Only report here. Respond sing position.                                                                       |
# |     |                      |                     |             |              |        |        |                                                 Husband chance black eye risk PM call. Entire owner into. College meeting yard right.                                                 |
# | 137 |       Kristen        |         Hunt        |      0      |      10      | 66.21  | 173.02 |                                                     Too marriage white approach everybody half. Pull find personal them fine art.                                                     |
# |     |                      |                     |             |              |        |        |                                                                   Sea newspaper discover compare record begin turn.                                                                   |
# | 138 |        James         |        Perez        |      0      |      56      | 84.21  | 153.32 |                                               Seem modern sometimes tend maintain. None ball loss front truth according provide rather.                                               |
# |     |                      |                     |             |              |        |        |                                         This score positive loss study least finish conference. Face teach party describe such bill join how.                                         |
# | 139 |         Amy          |        Jacobs       |      0      |      9       | 58.33  | 153.9  |              Entire wind answer two science reduce serious. Half result too suddenly could. Policy risk small recognize surface. Statement staff others sort cup section.             |
# | 140 |        Scott         |        Jones        |      0      |      61      | 51.69  | 170.25 |                             And join although minute ready fish. Single yourself continue involve most ability. Clear join office continue citizen study.                             |
# |     |                      |                     |             |              |        |        |                                                         Very dark nice safe ability tend. Real gas worker final meet born eat.                                                        |
# | 141 |        Daniel        |      Stevenson      |      0      |      6       | 86.07  | 185.59 |                  Head without positive building. Look thousand tend national shoulder challenge. Left have long series a. Return a thus special matter society this.                  |
# | 142 |        James         |        Newton       |      0      |      74      | 82.14  | 174.72 |                           Most student floor market box increase fear where. Happy tonight ago boy. Memory environment special factor per ready generation.                           |
# | 143 |        Blake         |        Rogers       |      1      |      10      | 68.15  | 179.53 |                                                              Star future us enjoy first purpose. Parent guess without a.                                                              |
# |     |                      |                     |             |              |        |        |                                                                              Group upon discussion stuff.                                                                             |
# |     |                      |                     |             |              |        |        |                                            Little alone me avoid language decade dog. Soon road strategy six around. Analysis amount near.                                            |
# | 144 |       Jonathan       |       Goodwin       |      0      |      30      | 50.48  | 172.35 |                          Direction child purpose remain all beyond. Boy thank establish adult successful. Head management officer describe other report fly.                          |
# | 145 |        Laura         |       Nichols       |      1      |      29      | 58.43  | 192.57 |                                         Carry evidence choice factor after them range. Miss perform similar become. Range fine available ask.                                         |
# | 146 |       Jessica        |        Brown        |      1      |      24      | 53.62  | 163.97 |                                                    Above take even successful house evening stand. Financial large statement mouth.                                                   |
# |     |                      |                     |             |              |        |        |                                                                                End American situation.                                                                                |
# |     |                      |                     |             |              |        |        |                                                                      Amount receive rise little. Member yeah tax.                                                                     |
# | 147 |        Dylan         |       Stewart       |      0      |      17      | 90.73  | 161.58 |                                    Foreign into own window everyone general use. And firm shake beyond onto your age. Range recent five be spring.                                    |
# |     |                      |                     |             |              |        |        |                                                                          Money top yet body after difference.                                                                         |
# | 148 |        Kevin         |       Leonard       |      0      |      91      | 90.61  | 192.39 |                                                   Man firm break receive development mission. Return option television clearly much.                                                  |
# |     |                      |                     |             |              |        |        |                                                          Music meeting boy sit item rich office. Someone sure wish property.                                                          |
# | 149 |         Ryan         |        Welch        |      0      |      0       | 70.97  | 173.11 |                                  Front break style choose down month design. Both Congress south arrive house when. Option about week sense article.                                  |
# |     |                      |                     |             |              |        |        |                                                                     Culture hand most question. Eat recognize bag.                                                                    |
# | 150 |        Rachel        |       Clements      |      0      |      89      | 86.95  | 155.14 |                                                            Realize must career physical. Inside police off. Fish long tax.                                                            |
# |     |                      |                     |             |              |        |        |                                                          Herself past while. Situation practice life he kitchen occur world.                                                          |
# | 151 |        Laurie        |      Armstrong      |      1      |      8       | 74.74  | 172.87 |                Daughter fire reduce use. Represent law chance fill reduce analysis. Blood compare company major degree. See glass drop main different region challenge.               |
# | 152 |         Lisa         |        Cortez       |      1      |      26      | 67.47  | 167.31 |                                                     Before rise sell usually defense election later reality. Protect debate part.                                                     |
# |     |                      |                     |             |              |        |        |                                            Fight take tell investment she capital. Down half resource. Also identify nearly movement safe.                                            |
# | 153 |      Christine       |       Williams      |      1      |      10      | 96.46  | 197.55 |                                             After begin site executive strategy statement. Budget our southern enter customer energy bank.                                            |
# |     |                      |                     |             |              |        |        |                                                                       Artist soldier reality million know good.                                                                       |
# |     |                      |                     |             |              |        |        |                                                                 Expert Republican also general us perform list dream.                                                                 |
# | 154 |         Ann          |        Cooper       |      1      |      95      | 50.22  | 195.21 |            Mind miss recent real production. Strong hand young stock. Want than history Republican tell sure reality organization. Campaign debate push professional play.            |
# | 155 |       Brandon        |         Reed        |      1      |      0       | 74.79  | 177.28 |                                              Each glass my evidence option. Defense little have. Executive black situation fish similar.                                              |
# | 156 |         Ryan         |        Fields       |      1      |      5       |  89.6  | 186.83 |                                            Spend protect clearly happy discussion have in push. Total film drop us join trouble low forget.                                           |
# | 157 |       Kimberly       |        Smith        |      1      |      6       | 60.26  | 194.41 |                                               Baby arm song notice feeling thought perform. Scene black themselves bill strong thousand.                                              |
# |     |                      |                     |             |              |        |        |                                                       Section group explain among. Later spend subject. Young toward room cause.                                                      |
# ...
# |     |             |              |        |        |                                                             Employee throw bag natural explain. Develop small peace table.                                                            |
# | 387 |      1      |      68      |  50.4  | 157.07 |                                                                             Worker mission indicate money.                                                                            |
# |     |             |              |        |        |                                                   Marriage continue group positive often. Certainly throw note glass goal Congress.                                                   |
# | 388 |      0      |      22      | 84.76  | 163.32 |                                            House soon down. Attorney save sit line of move. Answer above young rather cause put close tree.                                           |
# |     |             |              |        |        |                                                                        Image foot family special garden chance.                                                                       |
# | 389 |      1      |      38      | 66.46  | 193.31 |                                                           Blood discuss run cup. Rest red everybody window important always.                                                          |
# | 390 |      0      |      31      | 99.19  | 168.2  |                                                                             Present truth dog even music.                                                                             |
# |     |             |              |        |        |                            Skill huge attack apply house never. Affect clear Congress notice happen. However feel without never family next today resource.                           |
# | 391 |      0      |      57      | 50.23  | 151.03 |                      Project of early technology maintain couple. Team far deep stage message magazine country. Letter already career fill smile prepare mission.                     |
# | 392 |      0      |      97      | 79.59  | 164.63 |                                                Government simple family. Better brother today oil growth worker. Concern natural cause.                                               |
# |     |             |              |        |        |                                                              Sense discuss model along. Sing reason road check statement.                                                             |
# |     |             |              |        |        |                                                                               A stop five business kid.                                                                               |
# | 393 |      0      |      55      |  56.9  | 199.8  |                                              Sell college success speech country fly figure your. Drive training material here activity.                                              |
# |     |             |              |        |        |                                            Difference call media worker. Section enough because these turn official. Book budget art admit.                                           |
# | 394 |      0      |      22      | 71.94  | 153.24 |                                                                                     Occur eat gas.                                                                                    |
# |     |             |              |        |        |                                                                                  Forget ahead arrive.                                                                                 |
# |     |             |              |        |        |                 Begin scientist economy last tell myself. Factor time peace community exist raise much. South town once per. Bit sit onto current note than southern.                 |
# | 395 |      1      |      63      | 99.41  | 164.55 |                                                                      Budget state college. Fund piece wall step.                                                                      |
# |     |             |              |        |        |                       Side hotel coach month generation know live food. Education man public lose affect against treat heart. Cup director true lawyer big hot.                       |
# | 396 |      1      |      38      | 91.94  | 157.61 |                                                        Fall sport energy side goal act event. Ever mention create environment.                                                        |
# |     |             |              |        |        |                                                Sure go guess prepare moment see home use. True heart remember performance market site.                                                |
# | 397 |      1      |      76      | 70.34  | 198.92 |                                                         End political stay cover method. Business range interesting discover.                                                         |
# |     |             |              |        |        |                                             Top difference activity thank better. Land effort analysis thank window rise number certainly.                                            |
# | 398 |      1      |      67      | 73.95  | 163.86 |                                                                         Fine measure the. Admit free how home.                                                                        |
# |     |             |              |        |        |                                                                     From whatever computer hear. Ever so will oil.                                                                    |
# |     |             |              |        |        |                                                                       Job training you finally probably itself.                                                                       |
# |     |             |              |        |        |                                                           Local stand day. Believe strategy family certain wait might white.                                                          |
# | 399 |      0      |      39      | 91.86  | 197.81 |                                         Card message type office agency at. Difference really dog. Loss beyond money manage here significant.                                         |
# | 400 |      0      |      29      | 52.62  | 155.32 |                                                   Author a everyone simply several with goal. List eat factor production move exist.                                                  |
# | 401 |      1      |      89      | 148.0  | 156.0  |                                                                                  test scenario obese                                                                                  |
# | 402 |   1******   |     30*      |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 403 |   1******   | 30********** |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 404 |   1*******  |   30*****    |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 405 |  1********* |   30*****    |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 406 |    1****    |  30*******   |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 407 |  1********  |   30*****    |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 409 |   1*******  |     35*      | 1650.0 | 165.0  |                                                                                         obese                                                                                         |
# | 410 |     1***    |   30******   |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 412 |     1**     |   30******   |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 416 |    1****    |   30******   |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 420 |    1*****   |     30*      |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 424 |     1***    |     30*      |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 428 |  1********  |  30*******   |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 432 | 1********** |     30*      |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 436 |    1*****   |  30*******   |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 440 |   1*******  |    30***     |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 442 | 1********** |     30*      |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 444 | 1********** |     30*      |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 446 |  1********  |    34***     | 100.0  | 165.0  |                                                                                      hafbhefkwah                                                                                      |
# | 447 |     1***    |   12******   |  13.0  | 1231.0 |                                                                                         jafja                                                                                         |
# | 448 |   1******   | 30********** |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 452 |  1********* | 11*********  | 123.0  |  75.0  |                                                                                          lean                                                                                         |
# | 453 | 1********** |  30********  |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 455 |  1********* |    23****    |  76.0  | 123.0  |                                                                                         dvdgtd                                                                                        |
# | 456 | 1********** |   30*****    |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 458 |  1********* | 30*********  |  80.0  | 175.0  |                                                                                      Test history                                                                                     |
# | 459 |   1******   |   30*****    | 650.0  | 170.0  |                                                                                      Test history                                                                                     |
# | 460 |     1***    |    30***     | 750.0  | 170.0  |                                                                                      Test history                                                                                     |
# | 461 |      1*     | 30*********  | 850.0  | 170.0  |                                                                                      Test history                                                                                     |
# | 462 |   1*******  |    12****    | 121.0  | 124.0  |                                                                                         vsfnsn                                                                                        |
# +-----+-------------+--------------+--------+--------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Access Control Test Passed.
# Testing Data Integrity...
# Original Record: {'id': 101, 'first_name': 'Frederick', 'last_name': 'Gaines', 'encrypted_gender': b'AiBMaRf//rqZatKrWe0ugPcToAUG792utgvn8P2xthM=', 'encrypted_age': b'+y5/l59FOheo06MmGZacggTT0JQPV4bNwMT/gxMr7dY=', 'weight': 100.0, 'height': 154.06, 'health_history': 'Some create trade cause above.\nIndustry music best model collection. Do here official a key special.', 'record_hash': b'298c2bf984013ee06e96acaea0e736e38604b80ee5c29f61bc4dc129b61b5156', 'key_gender': b'3giLCNAvvMn40qiCI37FGczMdGt+fPPLpjUOT4bCNH8=', 'key_age': b'GrrhtjEwhRjSUwQY6gdammRXMGFa0AVJw0ovsARhQm4='}
# Modified Record: {'id': 101, 'first_name': 'Frederick', 'last_name': 'Gaines', 'encrypted_gender': b'AiBMaRf//rqZatKrWe0ugPcToAUG792utgvn8P2xthM=', 'encrypted_age': b'+y5/l59FOheo06MmGZacggTT0JQPV4bNwMT/gxMr7dY=', 'weight': 100.0, 'height': 154.06, 'health_history': 'Some create trade cause above.\nIndustry music best model collection. Do here official a key special.', 'record_hash': b'31c7ae6c849aadb74db64cb4dba7840df787d094792065d53461a3311e08b6f9', 'key_gender': b'3giLCNAvvMn40qiCI37FGczMdGt+fPPLpjUOT4bCNH8=', 'key_age': b'GrrhtjEwhRjSUwQY6gdammRXMGFa0AVJw0ovsARhQm4='}
# Data Integrity Test Passed.
# Testing Data Confidentiality...
# Data Confidentiality Test Passed.

# %%
#General Test for functionality
def establish_connection():
    mysql_password = getpass('Enter MySQL password for testing: ')
    connection = pymysql.connect(
        host='localhost',
        user='root',
        password=mysql_password,
        database='healthdetailsdb',
        charset='utf8mb4',
        cursorclass=pymysql.cursors.DictCursor
    )
    return connection

def test_data_integrity(connection):
    print("Testing Data Integrity...")
    cursor = connection.cursor()
    test_data = {
        'first_name': 'Test',
        'last_name': 'User',
        'gender': True,  # Assuming True for Male, False for Female
        'age': 30,
        'weight': 70.0,
        'height': 175.0,
        'health_history': 'Test history',
        'record_hash': ''  # Placeholder for record hash
    }
    insert_patient_data(connection, cursor, test_data, 'admin')
    cursor.execute("SELECT * FROM patient_info WHERE first_name = 'Test' AND last_name = 'User'")
    row = cursor.fetchone()
    assert row is not None, "Data insertion failed"
    # Tamper with the data
    cursor.execute("UPDATE patient_info SET weight = 80.0 WHERE first_name = 'Test' AND last_name = 'User'")
    connection.commit()
    # Try retrieving data
    cursor.execute("SELECT * FROM patient_info WHERE first_name = 'Test' AND last_name = 'User'")
    tampered_row = cursor.fetchone()
    assert tampered_row['weight'] != test_data['weight'], "Data integrity test failed: Tampered data not detected"
    print("Data Integrity test passed.")

def test_role_based_access_control(connection):
    print("Testing Role-Based Access Control...")
    cursor = connection.cursor()
    # Assuming 'admin' role has access to all fields and 'user' role has restricted access
    admin_role = 'admin'
    user_role = 'user'
    
    cursor.execute("SELECT COUNT(*) FROM patient_info")
    total_records = cursor.fetchone()['COUNT(*)']

    cursor.execute("SELECT COUNT(*) FROM patient_info WHERE key_gender IS NOT NULL AND key_age IS NOT NULL")
    accessible_records_admin = cursor.fetchone()['COUNT(*)']

    cursor.execute("SELECT COUNT(*) FROM patient_info WHERE key_gender IS NULL AND key_age IS NULL")
    accessible_records_user = cursor.fetchone()['COUNT(*)']

    assert accessible_records_admin == total_records, "Admin should access all records"
    assert accessible_records_user < total_records, "User should have restricted access"
    print("Role-Based Access Control test passed.")

def test_user_authentication(connection):
    print("Testing User Authentication...")
    cursor = connection.cursor()
    test_username = "test_user"
    test_password = "test_password"

    # Create a test user
    password_hash = bcrypt.hashpw(test_password.encode('utf-8'), bcrypt.gensalt())
    cursor.execute("""
        INSERT INTO user_credentials (username, password_hash, role) 
        VALUES (%s, %s, 'user') ON DUPLICATE KEY UPDATE password_hash = %s
    """, (test_username, password_hash, password_hash))
    connection.commit()

    # Attempt to authenticate
    cursor.execute("""
        SELECT password_hash FROM user_credentials 
        WHERE username = %s
    """, (test_username,))
    user_record = cursor.fetchone()
    assert user_record and bcrypt.checkpw(test_password.encode('utf-8'), user_record['password_hash']), "Authentication failed"
    print("User Authentication test passed.")

def test_aes_encryption_for_other_attributes(connection):
    print("Testing AES Encryption for Other Attributes...")
    cursor = connection.cursor()

    # Test encryption of a sample data
    test_data = "test_data"
    
    # Generate a valid AES key
    valid_aes_key = generate_aes_key()

    encrypted_data = encrypt_data_aes(test_data, valid_aes_key)
    decrypted_data = decrypt_data_aes(encrypted_data, valid_aes_key)
    assert decrypted_data == test_data, "AES encryption/decryption failed"
    print("AES Encryption test passed.")
    
def test_general_functionality(connection):
    print("Testing General Functionality...")
    cursor = connection.cursor()

    # Test adding a new patient
    patient_data = {
        'first_name': 'Test',
        'last_name': 'Patient',
        'gender': True,
        'age': 30,
        'weight': 60.0,
        'height': 170.0,
        'health_history': 'Test history',
        'record_hash': ''  # Placeholder for record hash
    }
    insert_patient_data(connection, cursor, patient_data, 'admin')
    cursor.execute("SELECT * FROM patient_info WHERE first_name = 'Test' AND last_name = 'Patient'")
    added_patient = cursor.fetchone()
    assert added_patient is not None, "Failed to add new patient"
    print("General Functionality test passed.")

def main():
    connection = establish_connection()
    
    test_data_integrity(connection)
    test_role_based_access_control(connection)
    test_user_authentication(connection)
    test_aes_encryption_for_other_attributes(connection)
    test_general_functionality(connection)

    connection.close()

if __name__ == "__main__":
    main()
# Out:
# Enter MySQL password for testing: ········
# Testing Data Integrity...
# Data inserted successfully.
# Data Integrity test passed.
# Testing Role-Based Access Control...
# Role-Based Access Control test passed.
# Testing User Authentication...
# User Authentication test passed.
# Testing AES Encryption for Other Attributes...
# AES Encryption test passed.
# Testing General Functionality...
# Data inserted successfully.
# General Functionality test passed.

# %%
# !pip install diagrams
# Out:
# Requirement already satisfied: diagrams in ./anaconda3/lib/python3.10/site-packages (0.23.4)
# Requirement already satisfied: graphviz<0.21.0,>=0.13.2 in ./anaconda3/lib/python3.10/site-packages (from diagrams) (0.20.1)
# Requirement already satisfied: jinja2<4.0,>=2.10 in ./anaconda3/lib/python3.10/site-packages (from diagrams) (3.1.2)
# Requirement already satisfied: typed-ast<2.0.0,>=1.5.4 in ./anaconda3/lib/python3.10/site-packages (from diagrams) (1.5.5)
# Requirement already satisfied: MarkupSafe>=2.0 in ./anaconda3/lib/python3.10/site-packages (from jinja2<4.0,>=2.10->diagrams) (2.1.1)

# %%
from diagrams import Diagram, Cluster
from diagrams.generic.database import SQL
from diagrams.generic.compute import Rack
from diagrams.generic.network import Firewall
from diagrams.generic.place import Datacenter
from diagrams.onprem.client import User

with Diagram("Secure Database-as-a-Service System Architecture", show="png", direction="LR"):

    with Cluster("User Interface Layer"):
        interface = User("User Interaction\n(login, registration, data I/O)")

    with Cluster("Application Layer"):
        with Cluster("Authentication Module"):
            auth = Rack("User Authentication")
        with Cluster("Data Processing Unit"):
            data_proc = Rack("Data Encryption/Decryption\nValidation, Integrity Checks\nCRUD Operations")

    with Cluster("Database Layer"):
        with Cluster("User Credentials Table"):
            user_db = SQL("User Credentials\n(username, password hash, role)")
        with Cluster("Patient Info Table"):
            patient_db = SQL("Patient Data\n(encrypted fields)")

    with Cluster("Admin-Specific Functions"):
        admin_funcs = Datacenter("Admin Functions\n(Add/Access Patient Data)")

    network = Firewall("Secure Network Communication")

    interface >> auth >> data_proc >> [user_db, patient_db]
    admin_funcs >> data_proc
    [user_db, patient_db] >> network

# %%
+-------------------+       +-------------------+       +-------------------+
| User Interaction  |       |   Database Layer  |       | Security Features |
| (Main Interface)  | <---->| (MySQL Database)  | <---->|   & Utilities     |
+-------------------+       +-------------------+       +-------------------+
      |                           |                            |
      | User Authentication       | Data Storage & Retrieval   | Encryption/Decryption
      | Role-Based Access Control | Data Integrity Checks      | Hash Generation
      | Data Entry & Retrieval    |                            | Sensitive Data Padding
      |                           |                            |
# Out:
#   Cell In[7], line 1
#     +-------------------+       +-------------------+       +-------------------+
#                                                                                  ^
# SyntaxError: invalid syntax
