# %%
import os
import pymysql
import bcrypt
from getpass import getpass
import base64
import hashlib
from cryptography.hazmat.primitives.ciphers import Cipher, algorithms, modes
from cryptography.hazmat.backends import default_backend
from prettytable import PrettyTable
from faker import Faker
import random

# AES Encryption setup
def generate_aes_key():
    return os.urandom(32)  # AES key size 

def encrypt_data_aes(data, key):
    iv = os.urandom(16)
    cipher = Cipher(algorithms.AES(key), modes.CBC(iv), backend=default_backend())
    encryptor = cipher.encryptor()
    padded_data = data + ' ' * (16 - len(data) % 16)
    encrypted_data = encryptor.update(padded_data.encode()) + encryptor.finalize()
    return base64.b64encode(iv + encrypted_data).decode('utf-8')

def decrypt_data_aes(data, key):
    try:
        data = base64.b64decode(data)
        iv = data[:16]
        encrypted_data = data[16:]
        cipher = Cipher(algorithms.AES(key), modes.CBC(iv), backend=default_backend())
        decryptor = cipher.decryptor()
        decrypted_data = decryptor.update(encrypted_data) + decryptor.finalize()
        return decrypted_data.rstrip().decode()
    except Exception as e:
        print(f"Decryption failed with error: {e}")
        return None

# Order-Preserving Encryption (OPE) setup 
OPE_KEY = 10  # Example key for OPE

def simple_ope_encrypt(value):
    return value * OPE_KEY

def simple_ope_decrypt(value):
    return value / OPE_KEY

def get_user_role(cursor, username):
    try:
        cursor.execute("""
            SELECT role FROM user_credentials 
            WHERE username = %s
        """, (username,))
        user_record = cursor.fetchone()
        if user_record:
            return user_record['role']
    except Exception as e:
        print(f"Error getting user role: {e}")
        return None
    
# Generate record hash for integrity check
def generate_record_hash(patient_data):
    record_str = ''.join(str(patient_data[field]) for field in sorted(patient_data))
    return hashlib.sha256(record_str.encode()).hexdigest()

# Validate patient data
def validate_patient_data(patient_data):
    if patient_data['age'] < 0 or patient_data['weight'] < 0.0:
        raise ValueError("Age and weight should not be negative.")
    if not patient_data['first_name'] or not patient_data['last_name']:
        raise ValueError("First name and last name are required.")

# Populate patient data
def populate_patient_data(connection, cursor, num_records=100):
    fake = Faker()
    for _ in range(num_records):
        patient_data = {
            'first_name': fake.first_name(),
            'last_name': fake.last_name(),
            'gender': random.choice([True, False]),  # True for Male, False for Female
            'age': random.randint(0, 100),
            'weight': round(random.uniform(50.0, 100.0), 2),
            'height': round(random.uniform(150.0, 200.0), 2),
            'health_history': fake.text(),
            'record_hash': ''  # Placeholder for record hash
        }
        patient_data['record_hash'] = generate_record_hash(patient_data)
        insert_patient_data(connection, cursor, patient_data, 'admin')

# Create user and patient tables
# Create user table
def create_user_table(cursor):
    cursor.execute("""
        CREATE TABLE IF NOT EXISTS user_credentials (
            id INT AUTO_INCREMENT PRIMARY KEY,
            username VARCHAR(100) UNIQUE NOT NULL,
            password_hash VARBINARY(256) NOT NULL,
            role ENUM('admin', 'user') NOT NULL
        );
    """)

# Create patient table
def create_patient_table(cursor):
    cursor.execute("""
        CREATE TABLE IF NOT EXISTS patient_info (
            id INT AUTO_INCREMENT PRIMARY KEY,
            first_name VARCHAR(100),
            last_name VARCHAR(100),
            encrypted_gender VARBINARY(256),
            encrypted_age VARBINARY(256),
            weight FLOAT,
            height FLOAT,
            health_history TEXT,
            record_hash VARBINARY(256) NOT NULL,
            key_gender VARBINARY(256),
            key_age VARBINARY(256)
        );
    """)

# Register new user
def register_user(connection, cursor, username, password, role):
    password_hash = bcrypt.hashpw(password.encode('utf-8'), bcrypt.gensalt())
    try:
        cursor.execute("""
            INSERT INTO user_credentials (username, password_hash, role) 
            VALUES (%s, %s, %s)
        """, (username, password_hash, role))
        connection.commit()
    except pymysql.err.IntegrityError:
        print("Username already exists.")

# Authenticate user
def authenticate_user(cursor, username, password):
    cursor.execute("""
        SELECT password_hash FROM user_credentials 
        WHERE username = %s
    """, (username,))
    user_record = cursor.fetchone()
    if user_record and bcrypt.checkpw(password.encode('utf-8'), user_record['password_hash']):
        return True
    else:
        return False
    
# Function to verify data integrity
def verify_data_integrity(patient_data, stored_hash):
    calculated_hash = generate_record_hash(patient_data)
    return calculated_hash == stored_hash

# Function to generate checksum for a set of records
def generate_checksum(records):
    checksum = 0
    for record in records:
        checksum ^= int(hashlib.sha256(str(record).encode()).hexdigest(), 16)
    return checksum

# Function to add randomized padding for sensitive data
def pad_sensitive_data(data):
    padding_length = random.randint(1, 10)  # Random padding length
    return data + ('*' * padding_length)

def insert_patient_data(connection, cursor, patient_data, user_role):
    try:
        if user_role != 'admin':  
            raise PermissionError("Permission denied.")
        validate_patient_data(patient_data)
        
        gender_str = pad_sensitive_data(str(int(patient_data['gender'])))  # Padding gender data
        age_str = pad_sensitive_data(str(patient_data['age']))  # Padding age data

        key_gender = generate_aes_key()
        key_age = generate_aes_key()

        encrypted_gender = encrypt_data_aes(gender_str, key_gender)
        encrypted_age = encrypt_data_aes(age_str, key_age)

        # Encrypt weight using OPE
        encrypted_weight = simple_ope_encrypt(patient_data['weight'])

        cursor.execute("""
            INSERT INTO patient_info (
                first_name, last_name, encrypted_gender, encrypted_age, weight, height, health_history, record_hash, key_gender, key_age
            ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
        """, (
            patient_data['first_name'],
            patient_data['last_name'],
            encrypted_gender,
            encrypted_age,
            encrypted_weight,
            patient_data['height'],
            patient_data['health_history'],
            patient_data['record_hash'],
            base64.b64encode(key_gender).decode('utf-8'),
            base64.b64encode(key_age).decode('utf-8')
        ))
        connection.commit()
        print("Data inserted successfully.")
    except Exception as e:
        print(f"Error inserting data: {e}")
        
# Designed to interactively collect patient information from the admin
def add_patient_data(connection, cursor):
    print("Adding new patient data.")

    try:
        patient_data = {
            'first_name': input("Enter patient's first name: "),
            'last_name': input("Enter patient's last name: "),
            'gender': bool(input("Enter patient's gender (True for male, False for female): ")),
            'age': int(input("Enter patient's age: ")),
            'weight': float(input("Enter patient's weight: ")),
            'height': float(input("Enter patient's height: ")),
            'health_history': input("Enter patient's health history: "),
            'record_hash': ''  # Placeholder for record hash
        }

        validate_patient_data(patient_data)
        patient_data['record_hash'] = generate_record_hash(patient_data)
        insert_patient_data(connection, cursor, patient_data, 'admin')
    except ValueError as e:
        print(f"Error: {e}")

def retrieve_patient_data(cursor, user_role, weight_range=None):
    query = "SELECT id, first_name, last_name, encrypted_gender, encrypted_age, key_gender, key_age, weight, height, health_history, record_hash FROM patient_info"

    if weight_range:
        # Convert the range into encrypted range
        encrypted_range = (simple_ope_encrypt(weight_range[0]), simple_ope_encrypt(weight_range[1]))
        query += f" WHERE weight BETWEEN {encrypted_range[0]} AND {encrypted_range[1]}"

    cursor.execute(query)
    rows = cursor.fetchall()

    checksum = generate_checksum(rows)  # Calculate checksum for fetched records
    print("Checksum of retrieved records:", checksum)

    if user_role == 'admin':
        table = PrettyTable(["ID", "First Name", "Last Name", "Gender", "Age", "Weight", "Height", "Health History"])
    else:
        table = PrettyTable(["ID", "Gender", "Age", "Weight", "Height", "Health History"])

    for row in rows:
        # Decrypt gender and age
        key_gender = base64.b64decode(row['key_gender']) if row['key_gender'] else None
        key_age = base64.b64decode(row['key_age']) if row['key_age'] else None

        decrypted_gender = decrypt_data_aes(row['encrypted_gender'], key_gender) if row['encrypted_gender'] and key_gender else "Unknown"
        decrypted_age = decrypt_data_aes(row['encrypted_age'], key_age) if row['encrypted_age'] and key_age else "Unknown"

        # Decrypt weight using OPE
        decrypted_weight = simple_ope_decrypt(row['weight'])

        if user_role == 'admin':
            table.add_row([
                row.get("id"),
                row.get("first_name"),
                row.get("last_name"),
                decrypted_gender,
                decrypted_age,
                decrypted_weight,
                row.get("height"),
                row.get("health_history")
            ])
        else:
            table.add_row([
                row.get("id"),
                decrypted_gender,
                decrypted_age,
                decrypted_weight,
                row.get("height"),
                row.get("health_history")
            ])

    print(table)

# %%
#General Test for functionality
def main():
    mysql_password = getpass('Enter MySQL password: ')
    conn = pymysql.connect(
        host='localhost',
        user='root',
        password=mysql_password,
        charset='utf8mb4'
    )

    cursor = conn.cursor()
    cursor.execute("CREATE DATABASE IF NOT EXISTS healthdetailsdb")
    conn.commit()

    conn.close()

    # Now connect to the newly created database
    connection = pymysql.connect(
        host='localhost',
        user='root',
        password=mysql_password,
        database='healthdetailsdb',
        charset='utf8mb4',
        cursorclass=pymysql.cursors.DictCursor
    )

    authenticated_user = None
    user_role = None

    while True:
        if not authenticated_user:
            print("1. Login")
            print("2. Register")
            print("3. Test User Authentication (Admin Only)")
            print("4. Test Access Control (Admin Only)")
            print("5. Exit")
            choice = input("Enter choice: ")

            if choice == '1':
                username = input("Enter username: ")
                password = getpass("Enter password: ")
                if authenticate_user(connection.cursor(), username, password):
                    print("Login successful.")
                    authenticated_user = username
                    user_role = get_user_role(connection.cursor(), username)  # Get the user's role
                else:
                    print("Login failed.")
            elif choice == '2':
                username = input("Enter new username: ")
                password = getpass("Enter new password: ")
                role = input("Enter role (admin/user): ").lower()
                register_user(connection, connection.cursor(), username, password, role)
            elif choice == '3':
                if authenticated_user and user_role == 'admin':
                    test_user_authentication(connection)
                else:
                    print("Admin access required.")

            elif choice == '4':
                if authenticated_user and user_role == 'admin':
                    test_access_control(connection)
                else:
                    print("Admin access required.")

            elif choice == '5':
                break

        else:
            print("\nLogged in as:", authenticated_user)
            print("4. View Patient Data")
            if user_role == 'admin':
                print("5. Add Patient Data")
            print("6. Logout")
            choice = input("Enter choice: ")

            if choice == '4':
                retrieve_patient_data(connection.cursor(), user_role)
            elif choice == '5' and user_role == 'admin':
                add_patient_data(connection, connection.cursor())
            elif choice == '6':
                authenticated_user = None
                user_role = None

    connection.close()

if __name__ == "__main__":
    main()
# Out:
# Enter MySQL password: ········
# 1. Login
# 2. Register
# 3. Test User Authentication (Admin Only)
# 4. Test Access Control (Admin Only)
# 5. Exit
# Enter choice: 1
# Enter username: AdminH
# Enter password: ········
# Login successful.
#
# Logged in as: AdminH
# 4. View Patient Data
# 5. Add Patient Data
# 6. Logout
# Enter choice: 4
# Checksum of retrieved records: 82146255578219489853451210379052979236079733972219602225429238903288582504517
# +-----+----------------------+---------------------+-------------+--------------+--------------------+--------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |  ID |      First Name      |      Last Name      |    Gender   |     Age      |       Weight       | Height |                                                                                     Health History                                                                                    |
# +-----+----------------------+---------------------+-------------+--------------+--------------------+--------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 101 |      Frederick       |        Gaines       |      1      |      47      |        12.0        | 154.06 |                                                                             Some create trade cause above.                                                                            |
# |     |                      |                     |             |              |                    |        |                                                         Industry music best model collection. Do here official a key special.                                                         |
# | 102 |       Derrick        |        White        |      0      |      92      |       6.207        | 169.1  |                                                       Data leader open first. Actually produce offer benefit break station bag.                                                       |
# |     |                      |                     |             |              |                    |        |                                             Sometimes impact lay second himself. Final response resource join law source. Must than skin.                                             |
# | 103 |        Julia         |       Francis       |      0      |      26      |       7.945        | 176.98 |         Student compare change something might including civil. Week station person some little particularly. Avoid garden professor information century point indicate serve.        |
# | 104 |         Erik         |      Alexander      |      1      |      81      | 6.6049999999999995 | 178.9  |                                                      Computer film doctor election hear southern staff our. Six station anything.                                                     |
# |     |                      |                     |             |              |                    |        |                                                       Thank shoulder although consumer probably people. Clear fly shoulder far.                                                       |
# | 105 |       Michael        |       Reynolds      |      1      |      2       |       6.589        | 169.94 |                               Section for successful down. Spend its computer well summer. Perform job doctor himself since popular coach relationship.                               |
# | 106 |         Amy          |         Lee         |      0      |      42      | 9.504999999999999  | 156.72 |                                                      Part nearly which nearly find ever. Speak gun reduce focus many we at deep.                                                      |
# |     |                      |                     |             |              |                    |        |                                              Drop perform them attention election other sport. Discover while about mind daughter could.                                              |
# | 107 |       Virginia       |        Lopez        |      0      |      5       |       6.808        | 197.21 |                                                                     Interview civil ever lead character life high.                                                                    |
# |     |                      |                     |             |              |                    |        |                                            Face ask owner above worry. Song reflect population occur notice help. West building help many.                                            |
# | 108 |       Brianna        |       Aguilar       |      1      |      80      |       8.093        | 179.65 |                                          Her rest nearly else. Necessary maybe long material way turn. Drug commercial drug thing where son.                                          |
# |     |                      |                     |             |              |                    |        |                                             Perform only if always miss factor. His company use property. Reflect wish rather head group.                                             |
# | 109 |         Dawn         |       Matthews      |      1      |      56      | 6.4430000000000005 | 175.41 |                                     Action kind at heart. Site like should safe role conference soon research. Dog suggest TV cause TV field back.                                    |
# | 110 |        Robert        |        Hughes       |      0      |      27      |        6.34        | 189.38 |                                                Only piece recognize technology character. Light reach various nothing model artist old.                                               |
# |     |                      |                     |             |              |                    |        |                                                                           After process any so million ball.                                                                          |
# |     |                      |                     |             |              |                    |        |                                                                            Whose husband indeed star idea.                                                                            |
# |     |                      |                     |             |              |                    |        |                                                                       Rise cup interest first receive or thank.                                                                       |
# | 111 |        Donna         |        Murray       |      0      |      98      |       5.244        | 175.45 |                                                                    Executive in lot produce. Away baby job include.                                                                   |
# |     |                      |                     |             |              |                    |        |                                            Simply traditional wonder one view. Project loss how range color picture. Seven let often water.                                           |
# | 112 |         Paul         |         Lee         |      0      |      62      | 6.901999999999999  | 177.48 |                                                  Ground protect despite push dark military these. Manage receive keep art important.                                                  |
# |     |                      |                     |             |              |                    |        |                                                                     Not here range. Know page white purpose event.                                                                    |
# | 113 |       Jeffery        |        Holden       |      0      |      70      |       5.064        | 167.34 |                                        Close customer speech play. Candidate off know modern whose Mr. Beautiful class series also experience.                                        |
# | 114 |        Ashley        |       Bridges       |      1      |      78      | 7.234999999999999  | 185.07 |                                  Energy Republican ahead these remember give. Financial remain happen there soon set. Color brother bar though fear.                                  |
# | 115 |       Jeffrey        |       Collier       |      0      |      38      |       7.883        | 197.95 |                                                  Never record whom represent economy especially. Hope medical travel feeling listen.                                                  |
# |     |                      |                     |             |              |                    |        |                                      Sing them hair face support first manage. Study street around into book. Rich skill sport white learn visit.                                     |
# | 116 |       Brandon        |        Walsh        |      1      |      71      |       9.422        | 157.59 |                                                    About professional treatment customer smile too bring. Effort form short piece.                                                    |
# |     |                      |                     |             |              |                    |        |                                                   They determine within sign after past. Site drive event base. Different teach his.                                                  |
# | 117 |       Jennifer       |       Mullins       |      1      |      64      | 7.393000000000001  | 170.27 |                                                            Weight else impact coach subject value. Spring over close team.                                                            |
# |     |                      |                     |             |              |                    |        |                               Government space imagine. Positive hit professional think reduce your ready. Trial per lead. Fire law answer measure his.                               |
# | 118 |        Rhonda        |       Williams      |      1      |      91      |       8.273        | 168.62 |                                                                         Concern risk camera simply recognize.                                                                         |
# |     |                      |                     |             |              |                    |        |                                                     Lot soon can toward room year. Leave go who knowledge subject lay onto today.                                                     |
# |     |                      |                     |             |              |                    |        |                                                                           Democrat during nature movie easy.                                                                          |
# | 119 |        Susan         |        Young        |      1      |      69      | 7.840999999999999  | 185.54 |                                          Political show fine what. Organization around though two wonder. Strong should eat focus technology.                                         |
# |     |                      |                     |             |              |                    |        |                                                                Present until late industry. True life this turn thing.                                                                |
# | 120 |        Sarah         |       Stevens       |      1      |      80      |       9.517        | 161.16 |                                                         Nation sense dog all their report. Whether physical support character.                                                        |
# | 121 |         John         |         Page        |      0      |      36      |       8.273        | 168.35 |                                                              Thing provide approach dream she. Take explain within draw.                                                              |
# |     |                      |                     |             |              |                    |        |                                       Threat energy big stuff drug line would. Ahead special soon green economic. Movement ask require response.                                      |
# | 122 |        James         |        Davis        |      1      |      22      |       8.654        | 165.74 |                                                             Whom box book field. Agency special decade since down brother.                                                            |
# |     |                      |                     |             |              |                    |        |                                     Performance small enough central position manage modern. Professional red spring ball find body relationship.                                     |
# | 123 |        Joshua        |        Morgan       |      1      |      58      | 6.215999999999999  | 190.76 |                  Thus hospital institution pressure though fall small part. Community ground far meeting ten contain religious. Body of turn all season chair our by.                 |
# |     |                      |                     |             |              |                    |        |                                                                               Sense cold role smile bit.                                                                              |
# | 124 |        Sandra        |        Martin       |      1      |      74      |       8.799        | 186.54 |                     Enter office happy instead night within. Skill boy during fine shoulder north building foreign. Power yard box dream anything door religious.                     |
# | 125 |       Patricia       |       Sullivan      |      0      |      10      |       7.269        | 161.08 |                                                          Movie decade quality step first. May range left way suddenly sense.                                                          |
# |     |                      |                     |             |              |                    |        |                                             Public both then expert against foot similar. Entire guy key almost operation safe road bank.                                             |
# | 126 |        Chloe         |         Ware        |      1      |      30      | 5.6770000000000005 | 177.67 |                                                                                Know but interview four.                                                                               |
# |     |                      |                     |             |              |                    |        |                                           Control fly car standard morning. Once these fast single identify. Mrs themselves here north car.                                           |
# |     |                      |                     |             |              |                    |        |                                                                            Plan summer list special often.                                                                            |
# | 127 |       Brandon        |       Johnson       |      0      |      82      | 7.5680000000000005 | 150.87 |                                                    Full win whether defense teach. Hotel research ten rule. While blood serve help.                                                   |
# |     |                      |                     |             |              |                    |        |                                                    Really capital bad leader. Color draw difference difference with way per stand.                                                    |
# | 128 |        David         |        Watts        |      0      |      72      | 6.093999999999999  | 160.82 |                                                         Real sense light local young. Along sport citizen. Color start house.                                                         |
# |     |                      |                     |             |              |                    |        |                                     Thing yet check stuff. You can president than sort oil special history. Debate must against major race alone.                                     |
# | 129 |        Ashley        |         Lara        |      0      |      20      |       9.546        | 169.55 |                                                            Next finish impact common my. Also amount scene one while clear.                                                           |
# |     |                      |                     |             |              |                    |        |                                                        Modern color chair campaign lot property. Work close environment night.                                                        |
# |     |                      |                     |             |              |                    |        |                                                                  Dream character fire reveal action because decision.                                                                 |
# | 130 |        Austin        |         Byrd        |      1      |      66      | 8.251000000000001  | 188.47 |                                  Treatment heavy capital work popular possible. Thousand which listen method factor collection. Heart blue truth bad.                                 |
# |     |                      |                     |             |              |                    |        |                                                           Explain let go whatever green. Tell fill others too anyone though.                                                          |
# | 131 |       Matthew        |        Taylor       |      0      |      13      | 9.934999999999999  | 195.02 |                                                         Particular attention continue collection put. No here much drop cell.                                                         |
# |     |                      |                     |             |              |                    |        |                                                                          Start general economy every reality.                                                                         |
# | 132 |        Dustin        |        Martin       |      0      |      89      |       9.758        | 167.57 |                                                          Play close billion often who single. Analysis everybody war himself.                                                         |
# |     |                      |                     |             |              |                    |        |                                      Rate blood condition big eight free car. Center risk relate trade. Interest admit key require officer east.                                      |
# | 133 |        Karen         |        Wright       |      1      |      36      | 9.190000000000001  | 190.9  |                                                         Design analysis door small community. Cover west capital vote public.                                                         |
# |     |                      |                     |             |              |                    |        |                                                                             Season traditional term learn.                                                                            |
# | 134 |        Caleb         |       Salazar       |      1      |      10      | 7.018000000000001  | 168.23 |                                                             Tough will interesting brother. A skill themselves try either.                                                            |
# |     |                      |                     |             |              |                    |        |                                          Entire everything price behind consumer tell improve. Until financial population want drug anything.                                         |
# | 135 |         Eric         |        Franco       |      0      |      13      | 7.837999999999999  | 187.21 |                                                   Writer accept talk. Think religious nor. Man lawyer list current ten information.                                                   |
# |     |                      |                     |             |              |                    |        |                                               Actually drop respond on fine certain. Professional score approach different matter hand.                                               |
# | 136 |        Kayla         |        Lewis        |      0      |      44      |       5.615        | 198.67 |                                                                    Especially name watch. News keep economic road.                                                                    |
# |     |                      |                     |             |              |                    |        |                                                                        Only report here. Respond sing position.                                                                       |
# |     |                      |                     |             |              |                    |        |                                                 Husband chance black eye risk PM call. Entire owner into. College meeting yard right.                                                 |
# | 137 |       Kristen        |         Hunt        |      0      |      10      | 6.6209999999999996 | 173.02 |                                                     Too marriage white approach everybody half. Pull find personal them fine art.                                                     |
# |     |                      |                     |             |              |                    |        |                                                                   Sea newspaper discover compare record begin turn.                                                                   |
# | 138 |        James         |        Perez        |      0      |      56      |       8.421        | 153.32 |                                               Seem modern sometimes tend maintain. None ball loss front truth according provide rather.                                               |
# |     |                      |                     |             |              |                    |        |                                         This score positive loss study least finish conference. Face teach party describe such bill join how.                                         |
# | 139 |         Amy          |        Jacobs       |      0      |      9       |       5.833        | 153.9  |              Entire wind answer two science reduce serious. Half result too suddenly could. Policy risk small recognize surface. Statement staff others sort cup section.             |
# | 140 |        Scott         |        Jones        |      0      |      61      |       5.169        | 170.25 |                             And join although minute ready fish. Single yourself continue involve most ability. Clear join office continue citizen study.                             |
# |     |                      |                     |             |              |                    |        |                                                         Very dark nice safe ability tend. Real gas worker final meet born eat.                                                        |
# | 141 |        Daniel        |      Stevenson      |      0      |      6       |       8.607        | 185.59 |                  Head without positive building. Look thousand tend national shoulder challenge. Left have long series a. Return a thus special matter society this.                  |
# | 142 |        James         |        Newton       |      0      |      74      |       8.214        | 174.72 |                           Most student floor market box increase fear where. Happy tonight ago boy. Memory environment special factor per ready generation.                           |
# | 143 |        Blake         |        Rogers       |      1      |      10      |       6.815        | 179.53 |                                                              Star future us enjoy first purpose. Parent guess without a.                                                              |
# |     |                      |                     |             |              |                    |        |                                                                              Group upon discussion stuff.                                                                             |
# |     |                      |                     |             |              |                    |        |                                            Little alone me avoid language decade dog. Soon road strategy six around. Analysis amount near.                                            |
# | 144 |       Jonathan       |       Goodwin       |      0      |      30      |       5.048        | 172.35 |                          Direction child purpose remain all beyond. Boy thank establish adult successful. Head management officer describe other report fly.                          |
# | 145 |        Laura         |       Nichols       |      1      |      29      |       5.843        | 192.57 |                                         Carry evidence choice factor after them range. Miss perform similar become. Range fine available ask.                                         |
# | 146 |       Jessica        |        Brown        |      1      |      24      |       5.362        | 163.97 |                                                    Above take even successful house evening stand. Financial large statement mouth.                                                   |
# |     |                      |                     |             |              |                    |        |                                                                                End American situation.                                                                                |
# |     |                      |                     |             |              |                    |        |                                                                      Amount receive rise little. Member yeah tax.                                                                     |
# | 147 |        Dylan         |       Stewart       |      0      |      17      |       9.073        | 161.58 |                                    Foreign into own window everyone general use. And firm shake beyond onto your age. Range recent five be spring.                                    |
# |     |                      |                     |             |              |                    |        |                                                                          Money top yet body after difference.                                                                         |
# | 148 |        Kevin         |       Leonard       |      0      |      91      |       9.061        | 192.39 |                                                   Man firm break receive development mission. Return option television clearly much.                                                  |
# |     |                      |                     |             |              |                    |        |                                                          Music meeting boy sit item rich office. Someone sure wish property.                                                          |
# | 149 |         Ryan         |        Welch        |      0      |      0       | 7.0969999999999995 | 173.11 |                                  Front break style choose down month design. Both Congress south arrive house when. Option about week sense article.                                  |
# |     |                      |                     |             |              |                    |        |                                                                     Culture hand most question. Eat recognize bag.                                                                    |
# | 150 |        Rachel        |       Clements      |      0      |      89      |       8.695        | 155.14 |                                                            Realize must career physical. Inside police off. Fish long tax.                                                            |
# |     |                      |                     |             |              |                    |        |                                                          Herself past while. Situation practice life he kitchen occur world.                                                          |
# | 151 |        Laurie        |      Armstrong      |      1      |      8       | 7.473999999999999  | 172.87 |                Daughter fire reduce use. Represent law chance fill reduce analysis. Blood compare company major degree. See glass drop main different region challenge.               |
# | 152 |         Lisa         |        Cortez       |      1      |      26      |       6.747        | 167.31 |                                                     Before rise sell usually defense election later reality. Protect debate part.                                                     |
# |     |                      |                     |             |              |                    |        |                                            Fight take tell investment she capital. Down half resource. Also identify nearly movement safe.                                            |
# | 153 |      Christine       |       Williams      |      1      |      10      | 9.645999999999999  | 197.55 |                                             After begin site executive strategy statement. Budget our southern enter customer energy bank.                                            |
# |     |                      |                     |             |              |                    |        |                                                                       Artist soldier reality million know good.                                                                       |
# |     |                      |                     |             |              |                    |        |                                                                 Expert Republican also general us perform list dream.                                                                 |
# | 154 |         Ann          |        Cooper       |      1      |      95      |       5.022        | 195.21 |            Mind miss recent real production. Strong hand young stock. Want than history Republican tell sure reality organization. Campaign debate push professional play.            |
# | 155 |       Brandon        |         Reed        |      1      |      0       | 7.479000000000001  | 177.28 |                                              Each glass my evidence option. Defense little have. Executive black situation fish similar.                                              |
# | 156 |         Ryan         |        Fields       |      1      |      5       | 8.959999999999999  | 186.83 |                                            Spend protect clearly happy discussion have in push. Total film drop us join trouble low forget.                                           |
# | 157 |       Kimberly       |        Smith        |      1      |      6       |       6.026        | 194.41 |                                               Baby arm song notice feeling thought perform. Scene black themselves bill strong thousand.                                              |
# |     |                      |                     |             |              |                    |        |                                                       Section group explain among. Later spend subject. Young toward room cause.                                                      |
# | 158 |       Jennifer       |        Smith        |      1      |      16      |       9.636        | 155.26 |                                        Really evening better seek play already now. Region style sit especially science machine computer tend.                                        |
# | 159 |        Amanda        |      Mccullough     |      1      |      12      |       8.464        | 187.41 |                                                    Condition other system fill worker. This wear career stage. About thousand rest.                                                   |
# |     |                      |                     |             |              |                    |        |                                    Forward story on age matter operation fast. Ground really table blue. Consumer property purpose our four maybe.                                    |
# | 160 |         Sara         |        Harvey       |      1      |      58      |       9.456        | 184.6  |                                Program draw officer industry ground sometimes. Much itself star method attack push high. Produce rock the simple than.                                |
# |     |                      |                     |             |              |                    |        |                                                                    Wear future school identify hope word sound use.                                                                   |
# | 161 |       Gregory        |       Lindsey       |      1      |      27      |       9.027        | 152.89 |                                                    Win always alone property. Control above especially building movement century a.                                                   |
# | 162 |       Desiree        |         Reed        |      1      |      83      |       5.652        | 197.32 |                                                                      Like down five. Director small live gun bag.                                                                     |
# |     |                      |                     |             |              |                    |        |                                                                      Age catch final operation wind age computer.                                                                     |
# | 163 |       Kristin        |       Hamilton      |      1      |      99      |       7.554        | 183.43 |                  Report recent nice range to. Ready again before usually professional. Stock food type picture despite. Task wife even staff have risk seat example.                  |
# | 164 |        Monica        |        Glover       |      1      |      86      |       5.104        | 198.85 |                                                           Clearly support heavy edge speak. Above close cover goal act bed.                                                           |
# |     |                      |                     |             |              |                    |        |                                 Item table act person movement candidate edge parent. Claim outside end thousand seem. Street citizen other grow good.                                |
# | 165 |       Gregory        |          Le         |      1      |      89      | 8.129999999999999  | 179.92 |                                             Visit during animal direction teacher event. Radio new hope approach strategy day during deal.                                            |
# |     |                      |                     |             |              |                    |        |                                                                      Contain color only their. Her book current.                                                                      |
# | 166 |       Crystal        |      Dickerson      |      0      |      1       | 6.2490000000000006 | 193.64 |               New fear yes learn design. Marriage likely partner today what at position control. Movie our evening process. Simply commercial strategy huge dinner find.              |
# | 167 |        Maria         |        Baker        |      0      |      10      |       6.389        | 177.62 |                                                 Alone cell society newspaper. Politics together child foreign response cut raise five.                                                |
# |     |                      |                     |             |              |                    |        |                                     Parent grow recent inside black name agency before. True month food kid serious reach. Ago through eight fire.                                    |
# | 168 |         Kent         |        Miller       |      1      |      77      |        6.95        | 191.52 |                                                                      To support again marriage billion watch bag.                                                                     |
# |     |                      |                     |             |              |                    |        |                                 Until admit prevent fight. Mind production including country which material prevent. Once near policy official speech.                                |
# | 169 |         Adam         |        Ewing        |      1      |      60      |       6.441        | 169.18 |                                         Away fire soon part check those writer. Way color response public join. Her when experience computer.                                         |
# | 170 |         Amy          |        Castro       |      0      |      14      | 6.2509999999999994 | 165.83 |                     Floor half short be sit bring feeling page. Lot above detail above since seat individual. Argue player pattern particularly present hold cut.                     |
# | 171 |       Brandon        |       Winters       |      1      |      96      |       6.386        | 191.06 |                  Give decide network. On measure system describe create himself. Environment water under almost reduce economy art. Radio could amount seven wall me.                 |
# | 172 |       Stephen        |        Moore        |      0      |      71      |       9.827        | 164.49 |                                                     Myself public bit director hundred write. Some far likely show draw research.                                                     |
# |     |                      |                     |             |              |                    |        |                                               West single almost government personal enough shake. Final itself everything into purpose.                                              |
# | 173 |       Valerie        |       Jackson       |      1      |      34      | 5.2829999999999995 | 163.61 |                                                             Deal car pay base air avoid. Event cause save fine summer new.                                                            |
# |     |                      |                     |             |              |                    |        |                                                  Tax whose behavior local see window employee. Offer person would war picture agent.                                                  |
# | 174 |        David         |        Wilson       |      0      |      35      |       9.282        | 161.3  |                                                 Trouble worker say stuff organization door. Check well attention drive stage training.                                                |
# |     |                      |                     |             |              |                    |        |                                                                            Doctor guy write mention world.                                                                            |
# | 175 |         Jeff         |       Lindsey       |      1      |      52      | 9.751999999999999  | 160.21 |                                           Near include city them collection concern. Night life one anyone third. Tax according region mind.                                          |
# | 176 |        Dillon        |        Cooper       |      0      |      51      |       8.314        | 150.74 |                                     Six kitchen decade artist. After clearly not sound happen. Make western ok simple whether pick administration.                                    |
# |     |                      |                     |             |              |                    |        |                                                    Almost where join surface. South happy there respond. Bit job popular probably.                                                    |
# | 177 |        David         |        James        |      0      |      55      |       5.044        | 154.29 |                                                                         Pick we get. Choice road write car on.                                                                        |
# | 178 |        Janet         |        Moreno       |      0      |      56      | 8.626000000000001  | 177.01 |                                                                                   Off student first.                                                                                  |
# |     |                      |                     |             |              |                    |        |                                                            Imagine play theory stage listen husband. Pay admit quite field.                                                           |
# |     |                      |                     |             |              |                    |        |                                                Record toward blood grow point nation miss. Others quite not sport bill degree special.                                                |
# | 179 |        Jerry         |       Anderson      |      0      |      63      |       7.305        | 181.21 |               Contain for remain ask defense. Science baby reason affect near national economy. Artist current doctor political book. Church star Congress through have.              |
# | 180 |        David         |      Alexander      |      1      |      50      | 6.520999999999999  | 156.5  |                            News quite accept piece physical evidence heavy write. Surface where piece mind receive. Range risk late listen view free movie.                           |
# | 181 |       Barbara        |       Morrison      |      0      |      41      | 7.593999999999999  | 160.1  |                                                Put but practice new traditional number bed anyone. Serve civil pressure travel expect.                                                |
# |     |                      |                     |             |              |                    |        |                                                                Sometimes listen administration beat. Film little open.                                                                |
# | 182 |        Martha        |       Hamilton      |      1      |      33      |       9.732        | 199.5  |                              Hospital discover gun wrong agree sort care. Try theory central traditional responsibility box. Boy suffer care camera like.                             |
# | 183 |        Grant         |        Jones        |      1      |      1       |       8.576        | 172.17 |                                                     Analysis place enter model raise job. Work myself whom sort two it recognize.                                                     |
# |     |                      |                     |             |              |                    |        |                                   Deal century by his medical red. Baby politics go mother not physical wife. Politics strategy manager information.                                  |
# | 184 |         Tina         |      Hernandez      |      1      |      73      | 8.309999999999999  | 191.37 |                                                       Ten chance responsibility various eight usually. Real young provide total.                                                      |
# |     |                      |                     |             |              |                    |        |                                      Apply drive hard key. Prepare before song want meeting by white. Sign degree art drop morning radio couple.                                      |
# | 185 |         Luis         |        Weaver       |      1      |     100      |       5.425        | 151.64 |                                                             Window consider more. Pick different to join turn nature low.                                                             |
# | 186 |         Lisa         |         Dunn        |      1      |      83      |       8.962        | 195.09 |                            Her democratic method wait fish politics. Oil same early recent us. Woman evening who dog. Child area collection western space.                            |
# | 187 |        Nicole        |       Gardner       |      0      |      45      |       8.052        | 170.62 |                              Although late with forward low check family. Our sometimes Democrat approach. Your oil music gas state security fight must.                              |
# | 188 |        Joseph        |        Hughes       |      1      |      65      | 6.601999999999999  | 183.27 |                                 Artist head feel fight generation professor rate. Small if product understand election century. Size card happy right.                                |
# |     |                      |                     |             |              |                    |        |                                                               By treat likely. Give condition message piece black stay.                                                               |
# | 189 |        Mandy         |        Potts        |      0      |      48      |       9.951        | 191.32 |                               Study either plan. Something personal scientist understand million up exist. Language dream morning rather simply change.                               |
# | 190 |        Andrea        |        Garcia       |      1      |      40      |       5.369        | 189.74 |                                                                          Action investment low Democrat they.                                                                         |
# ...
# | 389 |        Tonya         |        Wilson       |      1      |      38      | 6.645999999999999  | 193.31 |                                                           Blood discuss run cup. Rest red everybody window important always.                                                          |
# | 390 |       Michael        |       Salazar       |      0      |      31      |       9.919        | 168.2  |                                                                             Present truth dog even music.                                                                             |
# |     |                      |                     |             |              |                    |        |                            Skill huge attack apply house never. Affect clear Congress notice happen. However feel without never family next today resource.                           |
# | 391 |        Pamela        |      Washington     |      0      |      57      |       5.023        | 151.03 |                      Project of early technology maintain couple. Team far deep stage message magazine country. Letter already career fill smile prepare mission.                     |
# | 392 |        Rachel        |        Marks        |      0      |      97      | 7.9590000000000005 | 164.63 |                                                Government simple family. Better brother today oil growth worker. Concern natural cause.                                               |
# |     |                      |                     |             |              |                    |        |                                                              Sense discuss model along. Sing reason road check statement.                                                             |
# |     |                      |                     |             |              |                    |        |                                                                               A stop five business kid.                                                                               |
# | 393 |       Kimberly       |        Powell       |      0      |      55      | 5.6899999999999995 | 199.8  |                                              Sell college success speech country fly figure your. Drive training material here activity.                                              |
# |     |                      |                     |             |              |                    |        |                                            Difference call media worker. Section enough because these turn official. Book budget art admit.                                           |
# | 394 |        Susan         |        Savage       |      0      |      22      |       7.194        | 153.24 |                                                                                     Occur eat gas.                                                                                    |
# |     |                      |                     |             |              |                    |        |                                                                                  Forget ahead arrive.                                                                                 |
# |     |                      |                     |             |              |                    |        |                 Begin scientist economy last tell myself. Factor time peace community exist raise much. South town once per. Bit sit onto current note than southern.                 |
# | 395 |        Nathan        |       Crawford      |      1      |      63      | 9.940999999999999  | 164.55 |                                                                      Budget state college. Fund piece wall step.                                                                      |
# |     |                      |                     |             |              |                    |        |                       Side hotel coach month generation know live food. Education man public lose affect against treat heart. Cup director true lawyer big hot.                       |
# | 396 |         Amy          |       Stewart       |      1      |      38      | 9.193999999999999  | 157.61 |                                                        Fall sport energy side goal act event. Ever mention create environment.                                                        |
# |     |                      |                     |             |              |                    |        |                                                Sure go guess prepare moment see home use. True heart remember performance market site.                                                |
# | 397 |        Julia         |       Anderson      |      1      |      76      | 7.034000000000001  | 198.92 |                                                         End political stay cover method. Business range interesting discover.                                                         |
# |     |                      |                     |             |              |                    |        |                                             Top difference activity thank better. Land effort analysis thank window rise number certainly.                                            |
# | 398 |       Jennifer       |      Gutierrez      |      1      |      67      | 7.3950000000000005 | 163.86 |                                                                         Fine measure the. Admit free how home.                                                                        |
# |     |                      |                     |             |              |                    |        |                                                                     From whatever computer hear. Ever so will oil.                                                                    |
# |     |                      |                     |             |              |                    |        |                                                                       Job training you finally probably itself.                                                                       |
# |     |                      |                     |             |              |                    |        |                                                           Local stand day. Believe strategy family certain wait might white.                                                          |
# | 399 |       Brittney       |       Kennedy       |      0      |      39      |       9.186        | 197.81 |                                         Card message type office agency at. Difference really dog. Loss beyond money manage here significant.                                         |
# | 400 |        Harold        |       Johnson       |      0      |      29      |       5.262        | 155.32 |                                                   Author a everyone simply several with goal. List eat factor production move exist.                                                  |
# | 401 |   test first name    |    test last name   |      1      |      89      |        14.8        | 156.0  |                                                                                  test scenario obese                                                                                  |
# | 402 |         Test         |         User        |   1******   |     30*      |        8.0         | 175.0  |                                                                                      Test history                                                                                     |
# | 403 |         Test         |         User        |   1******   | 30********** |        8.0         | 175.0  |                                                                                      Test history                                                                                     |
# | 404 |         Test         |         User        |   1*******  |   30*****    |        8.0         | 175.0  |                                                                                      Test history                                                                                     |
# | 405 |         Test         |         User        |  1********* |   30*****    |        8.0         | 175.0  |                                                                                      Test history                                                                                     |
# | 406 |         Test         |         User        |    1****    |  30*******   |        8.0         | 175.0  |                                                                                      Test history                                                                                     |
# | 407 |         Test         |         User        |  1********  |   30*****    |        8.0         | 175.0  |                                                                                      Test history                                                                                     |
# | 409 |    Testfirstname1    |    testlastname1    |   1*******  |     35*      |       165.0        | 165.0  |                                                                                         obese                                                                                         |
# | 410 |         Test         |         User        |     1***    |   30******   |        8.0         | 175.0  |                                                                                      Test history                                                                                     |
# | 412 |         Test         |         User        |     1**     |   30******   |        8.0         | 175.0  |                                                                                      Test history                                                                                     |
# | 416 |         Test         |         User        |    1****    |   30******   |        8.0         | 175.0  |                                                                                      Test history                                                                                     |
# | 420 |         Test         |         User        |    1*****   |     30*      |        8.0         | 175.0  |                                                                                      Test history                                                                                     |
# | 424 |         Test         |         User        |     1***    |     30*      |        8.0         | 175.0  |                                                                                      Test history                                                                                     |
# | 428 |         Test         |         User        |  1********  |  30*******   |        8.0         | 175.0  |                                                                                      Test history                                                                                     |
# | 432 |         Test         |         User        | 1********** |     30*      |        8.0         | 175.0  |                                                                                      Test history                                                                                     |
# | 436 |         Test         |         User        |    1*****   |  30*******   |        8.0         | 175.0  |                                                                                      Test history                                                                                     |
# | 437 |         Test         |       Patient0      |   1*******  |   30*****    |        65.0        | 170.0  |                                                                                      Test history                                                                                     |
# | 438 |         Test         |       Patient1      |  1********* |    30***     |        75.0        | 170.0  |                                                                                      Test history                                                                                     |
# | 439 |         Test         |       Patient2      |    1****    | 30*********  |        85.0        | 170.0  |                                                                                      Test history                                                                                     |
# | 440 |         Test         |         User        |   1*******  |    30***     |        8.0         | 175.0  |                                                                                      Test history                                                                                     |
# | 441 |         Test         |       Patient       |  1********* | 30********** |        6.0         | 170.0  |                                                                                      Test history                                                                                     |
# | 442 |         Test         |         User        | 1********** |     30*      |        8.0         | 175.0  |                                                                                      Test history                                                                                     |
# | 443 |         Test         |       Patient       |   1*******  |  30********  |        6.0         | 170.0  |                                                                                      Test history                                                                                     |
# | 444 |         Test         |         User        | 1********** |     30*      |        8.0         | 175.0  |                                                                                      Test history                                                                                     |
# | 445 |         Test         |       Patient       |   1*******  |    30****    |        6.0         | 170.0  |                                                                                      Test history                                                                                     |
# | 446 | Testpatientfirstname | testpatientlastname |  1********  |    34***     |        10.0        | 165.0  |                                                                                      hafbhefkwah                                                                                      |
# | 447 |        test1         |        test2        |     1***    |   12******   |        1.3         | 1231.0 |                                                                                         jafja                                                                                         |
# +-----+----------------------+---------------------+-------------+--------------+--------------------+--------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Logged in as: AdminH
# 4. View Patient Data
# 5. Add Patient Data
# 6. Logout
# Enter choice: 6
# 1. Login
# 2. Register
# 3. Test User Authentication (Admin Only)
# 4. Test Access Control (Admin Only)
# 5. Exit
# Enter choice: 4
# Admin access required.
# 1. Login
# 2. Register
# 3. Test User Authentication (Admin Only)
# 4. Test Access Control (Admin Only)
# 5. Exit
# Enter choice: 5

# %%
#OVERALL SCENARIO TESTING FOR FINAL REPORT and as per REQUIREMENTS
def establish_connection():
    mysql_password = getpass('Enter MySQL password for testing: ')
    connection = pymysql.connect(
        host='localhost',
        user='root',
        password=mysql_password,
        database='healthdetailsdb',
        charset='utf8mb4',
        cursorclass=pymysql.cursors.DictCursor
    )
    return connection

def test_ope_functionality(connection):
    print("Testing OPE Functionality...")
    test_weight = 75.0  # Example weight
    encrypted_weight = simple_ope_encrypt(test_weight)
    decrypted_weight = simple_ope_decrypt(encrypted_weight)
    assert decrypted_weight == test_weight, "OPE decryption did not return the original value"
    print("OPE Functionality test passed.")
    
def test_ope_range_query(connection):
    print("Testing OPE Range Query...")
    cursor = connection.cursor()

    # Define the weight range for the query
    weight_range_min = 70.0
    weight_range_max = 80.0

    # Encrypt the range limits
    encrypted_min = simple_ope_encrypt(weight_range_min)
    encrypted_max = simple_ope_encrypt(weight_range_max)

    # Perform the range query
    cursor.execute("""
        SELECT * FROM patient_info
        WHERE weight BETWEEN %s AND %s
    """, (encrypted_min, encrypted_max))

    # Fetch and decrypt the results
    records = cursor.fetchall()
    for record in records:
        decrypted_weight = simple_ope_decrypt(record['weight'])
        assert weight_range_min <= decrypted_weight <= weight_range_max, "Record out of range"

    print("OPE Range Query test passed.")

def test_data_integrity(connection):
    print("Testing Data Integrity...")
    cursor = connection.cursor()
    test_data = {
        'first_name': 'Test',
        'last_name': 'User',
        'gender': True,  # Assuming True for Male, False for Female
        'age': 30,
        'weight': 70.0,
        'height': 175.0,
        'health_history': 'Test history',
        'record_hash': ''  # Placeholder for record hash
    }
    insert_patient_data(connection, cursor, test_data, 'admin')
    cursor.execute("SELECT * FROM patient_info WHERE first_name = 'Test' AND last_name = 'User'")
    row = cursor.fetchone()
    assert row is not None, "Data insertion failed"
    # Tamper with the data
    cursor.execute("UPDATE patient_info SET weight = 80.0 WHERE first_name = 'Test' AND last_name = 'User'")
    connection.commit()
    # Try retrieving data
    cursor.execute("SELECT * FROM patient_info WHERE first_name = 'Test' AND last_name = 'User'")
    tampered_row = cursor.fetchone()
    assert tampered_row['weight'] != test_data['weight'], "Data integrity test failed: Tampered data not detected"
    print("Data Integrity test passed.")

def test_role_based_access_control(connection):
    print("Testing Role-Based Access Control...")
    cursor = connection.cursor()
    # Assuming 'admin' role has access to all fields and 'user' role has restricted access
    admin_role = 'admin'
    user_role = 'user'
    
    cursor.execute("SELECT COUNT(*) FROM patient_info")
    total_records = cursor.fetchone()['COUNT(*)']

    cursor.execute("SELECT COUNT(*) FROM patient_info WHERE key_gender IS NOT NULL AND key_age IS NOT NULL")
    accessible_records_admin = cursor.fetchone()['COUNT(*)']

    cursor.execute("SELECT COUNT(*) FROM patient_info WHERE key_gender IS NULL AND key_age IS NULL")
    accessible_records_user = cursor.fetchone()['COUNT(*)']

    assert accessible_records_admin == total_records, "Admin should access all records"
    assert accessible_records_user < total_records, "User should have restricted access"
    print("Role-Based Access Control test passed.")

def test_user_authentication(connection):
    print("Testing User Authentication...")
    cursor = connection.cursor()
    test_username = "test_user"
    test_password = "test_password"

    # Create a test user
    password_hash = bcrypt.hashpw(test_password.encode('utf-8'), bcrypt.gensalt())
    cursor.execute("""
        INSERT INTO user_credentials (username, password_hash, role) 
        VALUES (%s, %s, 'user') ON DUPLICATE KEY UPDATE password_hash = %s
    """, (test_username, password_hash, password_hash))
    connection.commit()

    # Attempt to authenticate
    cursor.execute("""
        SELECT password_hash FROM user_credentials 
        WHERE username = %s
    """, (test_username,))
    user_record = cursor.fetchone()
    assert user_record and bcrypt.checkpw(test_password.encode('utf-8'), user_record['password_hash']), "Authentication failed"
    print("User Authentication test passed.")

def test_aes_encryption_for_other_attributes(connection):
    print("Testing AES Encryption for Other Attributes...")
    cursor = connection.cursor()

    # Test encryption of a sample data
    test_data = "test_data"
    
    # Generate a valid AES key
    valid_aes_key = generate_aes_key()

    encrypted_data = encrypt_data_aes(test_data, valid_aes_key)
    decrypted_data = decrypt_data_aes(encrypted_data, valid_aes_key)
    assert decrypted_data == test_data, "AES encryption/decryption failed"
    print("AES Encryption test passed.")
    
def test_general_functionality(connection):
    print("Testing General Functionality...")
    cursor = connection.cursor()

    # Clearing previous test data (if needed)
    cursor.execute("DELETE FROM patient_info WHERE first_name = 'Test' AND last_name LIKE 'Patient%'")
    connection.commit()

    # Test adding new patients with varied weights
    for i, weight in enumerate([65.0, 75.0, 85.0]):
        patient_data = {
            'first_name': 'Test',
            'last_name': f'Patient{i}',
            'gender': True,
            'age': 30,
            'weight': weight,
            'height': 170.0,
            'health_history': 'Test history',
            'record_hash': ''  # Placeholder for record hash
        }
        insert_patient_data(connection, cursor, patient_data, 'admin')

    # Retrieve and check weights
    cursor.execute("SELECT weight FROM patient_info WHERE first_name = 'Test' AND last_name LIKE 'Patient%'")
    retrieved_weights = [row['weight'] for row in cursor.fetchall()]
    assert len(retrieved_weights) == 3, f"Expected 3 records, got {len(retrieved_weights)}"

    # Check if the order of weights is preserved
    for i in range(len(retrieved_weights) - 1):
        assert retrieved_weights[i] < retrieved_weights[i + 1], "Retrieved weights are not in the correct order"

    print("General Functionality test passed.")
    
def main():
    connection = establish_connection()
    
    test_ope_functionality(connection)
    test_ope_range_query(connection)
    test_data_integrity(connection)
    test_role_based_access_control(connection)
    test_user_authentication(connection)
    test_aes_encryption_for_other_attributes(connection)
    test_general_functionality(connection)

    connection.close()

if __name__ == "__main__":
    main()
# Out:
# Enter MySQL password for testing: ········
# Testing OPE Functionality...
# OPE Functionality test passed.
# Testing OPE Range Query...
# OPE Range Query test passed.
# Testing Data Integrity...
# Data inserted successfully.
# Data Integrity test passed.
# Testing Role-Based Access Control...
# Role-Based Access Control test passed.
# Testing User Authentication...
# User Authentication test passed.
# Testing AES Encryption for Other Attributes...
# AES Encryption test passed.
# Testing General Functionality...
# Data inserted successfully.
# Data inserted successfully.
# Data inserted successfully.
# General Functionality test passed.

# %%
import diagrams.generic.compute as compute
print(dir(compute))
# Out:
# ['Rack', '_Compute', '_Generic', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__']

# %%
from diagrams import Diagram, Cluster
from diagrams.generic.database import SQL
from diagrams.generic.compute import Rack
from diagrams.generic.network import Firewall
from diagrams.generic.place import Datacenter
from diagrams.onprem.client import User

with Diagram("Secure DBaaS System Architecture", show="png", direction="LR"):

    with Cluster("User Interface Layer"):
        interface = User("User Interaction")

    with Cluster("Application Layer"):
        with Cluster("Authentication Module"):
            auth = Rack("Auth Module")
        with Cluster("Data Processing Unit"):
            data_proc = Rack("Data Proc Unit")
            encryption = Rack("AES Encryption")
            decryption = Rack("AES Decryption")
            ope = Rack("OPE")

    with Cluster("Database Layer"):
        with Cluster("User Credentials Table"):
            user_db = SQL("User DB")
        with Cluster("Patient Info Table"):
            patient_db = SQL("Patient DB")

    with Cluster("Admin Functions"):
        admin_funcs = Datacenter("Admin Ops")

    network = Firewall("Network Comm")

    interface >> auth >> data_proc
    data_proc >> [encryption, decryption, ope]
    encryption >> user_db
    decryption >> patient_db
    ope >> patient_db
    admin_funcs >> data_proc
    [user_db, patient_db] >> network
